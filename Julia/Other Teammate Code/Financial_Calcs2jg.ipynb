# %%
# Import necessary libraries
import pandas as pd, shutil, os
import yfinance as yf
import datetime as dt
import numpy as np
from pathlib import Path
import json
import sqlalchemy

# %%
# Get S&P 500 tickers
sp500_tickers = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")[0]
sp500_tickers = sp500_tickers.Symbol.to_list()
# sp500_tickers

# %%
# Clean Tickers of periods
sp500_tickers = [x.replace(".", "-") for x in sp500_tickers]
# sp500_tickers

# %%
# Define Start and End dates for hist. data(5 yr)
end_date = dt.datetime.now().date().isoformat()
start_date = dt.datetime.now() - dt.timedelta(weeks=26)
start_date = start_date.date().isoformat()
start_date
# Out:
# '2021-02-14'

# %%
# Removes old Stock_Data folder and replaces it with a new, empty one
shutil.rmtree("Stock_Data")
os.mkdir("Stock_Data")

# %%
sp_data = yf.download(sp500_tickers, period="5d", group_by="Ticker")

sp_data
# Out:
# [*********************100%***********************]  505 of 505 completed
#                   GNRC                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 2021-08-09  414.000000  419.850006  411.480011  417.859985  417.859985
# 2021-08-10  420.000000  426.649994  415.089996  419.089996  419.089996
# 2021-08-11  419.359985  420.660004  411.029999  417.220001  417.220001
# 2021-08-12  415.109985  423.799988  413.670013  423.320007  423.320007
# 2021-08-13  423.549988  424.579987  411.839996  414.100006  414.100006
#
#                           TSLA                                      ...  \
#             Volume        Open        High         Low       Close  ...
# Date                                                                ...
# 2021-08-09  473400  710.169983  719.030029  705.130005  713.760010  ...
# 2021-08-10  495400  713.989990  716.590027  701.880005  709.989990  ...
# 2021-08-11  601500  712.710022  715.179993  704.210022  707.820007  ...
# 2021-08-12  672800  706.340027  722.799988  699.400024  722.250000  ...
# 2021-08-13  530200  723.710022  729.900024  714.340027  717.169983  ...
#
#                    STZ                                          WMT  \
#                    Low       Close   Adj Close   Volume        Open
# Date
# 2021-08-09  217.009995  217.190002  217.190002   936800  145.910004
# 2021-08-10  217.240005  218.059998  218.059998  1292000  146.970001
# 2021-08-11  212.750000  213.399994  213.399994  2648900  149.509995
# 2021-08-12  211.020004  211.940002  211.940002  1579300  149.000000
# 2021-08-13  212.000000  213.639999  213.639999  1111000  149.380005
#
#
#                   High         Low       Close   Adj Close    Volume
# Date
# 2021-08-09  146.479996  145.399994  145.580002  145.046249   5270600
# 2021-08-10  148.949997  146.250000  148.679993  148.134872  12754000
# 2021-08-11  151.580002  149.160004  150.009995  149.459991  13818600
# 2021-08-12  150.210007  148.809998  149.059998  149.059998   6089700
# 2021-08-13  150.360001  149.160004  149.529999  149.529999   5321900
#
# [5 rows x 3030 columns]

# %%
database_connection_string = 'sqlite:///'

engine = sqlalchemy.create_engine(database_connection_string)

engine
# Out:
# Engine(sqlite:///)

# %%
sp_data.to_sql(
    'sp_data',
    engine,
    index=False,
    if_exists='replace'
)

engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1705                     self.dialect.do_execute(
# -> 1706                         cursor, statement, parameters, context
#    1707                     )
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# OperationalError: too many columns on sp_data
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-9-65a8f5086d7d> in <module>
#       3     engine,
#       4     index=False,
# ----> 5     if_exists='replace'
#       6 )
#       7
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2787             chunksize=chunksize,
#    2788             dtype=dtype,
# -> 2789             method=method,
#    2790         )
#    2791
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     608         chunksize=chunksize,
#     609         dtype=dtype,
# --> 610         method=method,
#     611     )
#     612
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404             dtype=dtype,
#    1405         )
# -> 1406         table.create()
#    1407
#    1408         from sqlalchemy import exc
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\io\sql.py in create(self)
#     745                 raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     746         else:
# --> 747             self._execute_create()
#     748
#     749     def _execute_insert(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\io\sql.py in _execute_create(self)
#     731         else:
#     732             self.table = self.table.tometadata(self.pd_sql.meta)
# --> 733         self.table.create()
#     734
#     735     def create(self):
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\sql\schema.py in create(self, bind, checkfirst)
#     941         if bind is None:
#     942             bind = _bind_or_error(self)
# --> 943         bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#     944
#     945     def drop(self, bind=None, checkfirst=False):
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3006     def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    3007         with self.begin() as conn:
# -> 3008             conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#    3009
#    3010     @util.deprecated_20(
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2014
#    2015         """
# -> 2016         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    2017
#    2018     @util.deprecated(
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\sql\visitors.py in traverse_single(self, obj, **kw)
#     481             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     482             if meth:
# --> 483                 return meth(obj, **kw)
#     484
#     485     def iterate(self, obj):
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\sql\ddl.py in visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     893                 table,
#     894                 include_foreign_key_constraints=  # noqa
# --> 895                     include_foreign_key_constraints,  # noqa
#     896             )
#     897             # fmt: on
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\sql\ddl.py in _execute_on_connection(self, connection, multiparams, params, execution_options)
#      76     ):
#      77         return connection._execute_ddl(
# ---> 78             self, multiparams, params, execution_options
#      79         )
#      80
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py in _execute_ddl(self, ddl, multiparams, params, execution_options)
#    1294             None,
#    1295             execution_options,
# -> 1296             compiled,
#    1297         )
#    1298         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1747         except BaseException as e:
#    1748             self._handle_dbapi_exception(
# -> 1749                 e, statement, parameters, cursor, context
#    1750             )
#    1751
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1928             elif should_wrap:
#    1929                 util.raise_(
# -> 1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#    1932             else:
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
#    1705                     self.dialect.do_execute(
# -> 1706                         cursor, statement, parameters, context
#    1707                     )
#    1708
#
# ~\anaconda3\envs\dev\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     690
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#     694     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) too many columns on sp_data
# [SQL:
# CREATE TABLE sp_data (
# 	"('Adj Close', 'A')" FLOAT,
# 	"('Adj Close', 'AAL')" FLOAT,
# 	"('Adj Close', 'AAP')" FLOAT,
# 	"('Adj Close', 'AAPL')" FLOAT,
# 	"('Adj Close', 'ABBV')" FLOAT,
# 	"('Adj Close', 'ABC')" FLOAT,
# 	"('Adj Close', 'ABMD')" FLOAT,
# 	"('Adj Close', 'ABT')" FLOAT,
# 	"('Adj Close', 'ACN')" FLOAT,
# 	"('Adj Close', 'ADBE')" FLOAT,
# 	"('Adj Close', 'ADI')" FLOAT,
# 	"('Adj Close', 'ADM')" FLOAT,
# 	"('Adj Close', 'ADP')" FLOAT,
# 	"('Adj Close', 'ADSK')" FLOAT,
# 	"('Adj Close', 'AEE')" FLOAT,
# 	"('Adj Close', 'AEP')" FLOAT,
# 	"('Adj Close', 'AES')" FLOAT,
# 	"('Adj Close', 'AFL')" FLOAT,
# 	"('Adj Close', 'AIG')" FLOAT,
# 	"('Adj Close', 'AIZ')" FLOAT,
# 	"('Adj Close', 'AJG')" FLOAT,
# 	"('Adj Close', 'AKAM')" FLOAT,
# 	"('Adj Close', 'ALB')" FLOAT,
# 	"('Adj Close', 'ALGN')" FLOAT,
# 	"('Adj Close', 'ALK')" FLOAT,
# 	"('Adj Close', 'ALL')" FLOAT,
# 	"('Adj Close', 'ALLE')" FLOAT,
# 	"('Adj Close', 'AMAT')" FLOAT,
# 	"('Adj Close', 'AMCR')" FLOAT,
# 	"('Adj Close', 'AMD')" FLOAT,
# 	"('Adj Close', 'AME')" FLOAT,
# 	"('Adj Close', 'AMGN')" FLOAT,
# 	"('Adj Close', 'AMP')" FLOAT,
# 	"('Adj Close', 'AMT')" FLOAT,
# 	"('Adj Close', 'AMZN')" FLOAT,
# 	"('Adj Close', 'ANET')" FLOAT,
# 	"('Adj Close', 'ANSS')" FLOAT,
# 	"('Adj Close', 'ANTM')" FLOAT,
# 	"('Adj Close', 'AON')" FLOAT,
# 	"('Adj Close', 'AOS')" FLOAT,
# 	"('Adj Close', 'APA')" FLOAT,
# 	"('Adj Close', 'APD')" FLOAT,
# 	"('Adj Close', 'APH')" FLOAT,
# 	"('Adj Close', 'APTV')" FLOAT,
# 	"('Adj Close', 'ARE')" FLOAT,
# 	"('Adj Close', 'ATO')" FLOAT,
# 	"('Adj Close', 'ATVI')" FLOAT,
# 	"('Adj Close', 'AVB')" FLOAT,
# 	"('Adj Close', 'AVGO')" FLOAT,
# 	"('Adj Close', 'AVY')" FLOAT,
# 	"('Adj Close', 'AWK')" FLOAT,
# 	"('Adj Close', 'AXP')" FLOAT,
# 	"('Adj Close', 'AZO')" FLOAT,
# 	"('Adj Close', 'BA')" FLOAT,
# 	"('Adj Close', 'BAC')" FLOAT,
# 	"('Adj Close', 'BAX')" FLOAT,
# 	"('Adj Close', 'BBWI')" FLOAT,
# 	"('Adj Close', 'BBY')" FLOAT,
# 	"('Adj Close', 'BDX')" FLOAT,
# 	"('Adj Close', 'BEN')" FLOAT,
# 	"('Adj Close', 'BF-B')" FLOAT,
# 	"('Adj Close', 'BIIB')" FLOAT,
# 	"('Adj Close', 'BIO')" FLOAT,
# 	"('Adj Close', 'BK')" FLOAT,
# 	"('Adj Close', 'BKNG')" FLOAT,
# 	"('Adj Close', 'BKR')" FLOAT,
# 	"('Adj Close', 'BLK')" FLOAT,
# 	"('Adj Close', 'BLL')" FLOAT,
# 	"('Adj Close', 'BMY')" FLOAT,
# 	"('Adj Close', 'BR')" FLOAT,
# 	"('Adj Close', 'BRK-B')" FLOAT,
# 	"('Adj Close', 'BSX')" FLOAT,
# 	"('Adj Close', 'BWA')" FLOAT,
# 	"('Adj Close', 'BXP')" FLOAT,
# 	"('Adj Close', 'C')" FLOAT,
# 	"('Adj Close', 'CAG')" FLOAT,
# 	"('Adj Close', 'CAH')" FLOAT,
# 	"('Adj Close', 'CARR')" FLOAT,
# 	"('Adj Close', 'CAT')" FLOAT,
# 	"('Adj Close', 'CB')" FLOAT,
# 	"('Adj Close', 'CBOE')" FLOAT,
# 	"('Adj Close', 'CBRE')" FLOAT,
# 	"('Adj Close', 'CCI')" FLOAT,
# 	"('Adj Close', 'CCL')" FLOAT,
# 	"('Adj Close', 'CDNS')" FLOAT,
# 	"('Adj Close', 'CDW')" FLOAT,
# 	"('Adj Close', 'CE')" FLOAT,
# 	"('Adj Close', 'CERN')" FLOAT,
# 	"('Adj Close', 'CF')" FLOAT,
# 	"('Adj Close', 'CFG')" FLOAT,
# 	"('Adj Close', 'CHD')" FLOAT,
# 	"('Adj Close', 'CHRW')" FLOAT,
# 	"('Adj Close', 'CHTR')" FLOAT,
# 	"('Adj Close', 'CI')" FLOAT,
# 	"('Adj Close', 'CINF')" FLOAT,
# 	"('Adj Close', 'CL')" FLOAT,
# 	"('Adj Close', 'CLX')" FLOAT,
# 	"('Adj Close', 'CMA')" FLOAT,
# 	"('Adj Close', 'CMCSA')" FLOAT,
# 	"('Adj Close', 'CME')" FLOAT,
# 	"('Adj Close', 'CMG')" FLOAT,
# 	"('Adj Close', 'CMI')" FLOAT,
# 	"('Adj Close', 'CMS')" FLOAT,
# 	"('Adj Close', 'CNC')" FLOAT,
# 	"('Adj Close', 'CNP')" FLOAT,
# 	"('Adj Close', 'COF')" FLOAT,
# 	"('Adj Close', 'COG')" FLOAT,
# 	"('Adj Close', 'COO')" FLOAT,
# 	"('Adj Close', 'COP')" FLOAT,
# 	"('Adj Close', 'COST')" FLOAT,
# 	"('Adj Close', 'CPB')" FLOAT,
# 	"('Adj Close', 'CPRT')" FLOAT,
# 	"('Adj Close', 'CRL')" FLOAT,
# 	"('Adj Close', 'CRM')" FLOAT,
# 	"('Adj Close', 'CSCO')" FLOAT,
# 	"('Adj Close', 'CSX')" FLOAT,
# 	"('Adj Close', 'CTAS')" FLOAT,
# 	"('Adj Close', 'CTLT')" FLOAT,
# 	"('Adj Close', 'CTSH')" FLOAT,
# 	"('Adj Close', 'CTVA')" FLOAT,
# 	"('Adj Close', 'CTXS')" FLOAT,
# 	"('Adj Close', 'CVS')" FLOAT,
# 	"('Adj Close', 'CVX')" FLOAT,
# 	"('Adj Close', 'CZR')" FLOAT,
# 	"('Adj Close', 'D')" FLOAT,
# 	"('Adj Close', 'DAL')" FLOAT,
# 	"('Adj Close', 'DD')" FLOAT,
# 	"('Adj Close', 'DE')" FLOAT,
# 	"('Adj Close', 'DFS')" FLOAT,
# 	"('Adj Close', 'DG')" FLOAT,
# 	"('Adj Close', 'DGX')" FLOAT,
# 	"('Adj Close', 'DHI')" FLOAT,
# 	"('Adj Close', 'DHR')" FLOAT,
# 	"('Adj Close', 'DIS')" FLOAT,
# 	"('Adj Close', 'DISCA')" FLOAT,
# 	"('Adj Close', 'DISCK')" FLOAT,
# 	"('Adj Close', 'DISH')" FLOAT,
# 	"('Adj Close', 'DLR')" FLOAT,
# 	"('Adj Close', 'DLTR')" FLOAT,
# 	"('Adj Close', 'DOV')" FLOAT,
# 	"('Adj Close', 'DOW')" FLOAT,
# 	"('Adj Close', 'DPZ')" FLOAT,
# 	"('Adj Close', 'DRE')" FLOAT,
# 	"('Adj Close', 'DRI')" FLOAT,
# 	"('Adj Close', 'DTE')" FLOAT,
# 	"('Adj Close', 'DUK')" FLOAT,
# 	"('Adj Close', 'DVA')" FLOAT,
# 	"('Adj Close', 'DVN')" FLOAT,
# 	"('Adj Close', 'DXC')" FLOAT,
# 	"('Adj Close', 'DXCM')" FLOAT,
# 	"('Adj Close', 'EA')" FLOAT,
# 	"('Adj Close', 'EBAY')" FLOAT,
# 	"('Adj Close', 'ECL')" FLOAT,
# 	"('Adj Close', 'ED')" FLOAT,
# 	"('Adj Close', 'EFX')" FLOAT,
# 	"('Adj Close', 'EIX')" FLOAT,
# 	"('Adj Close', 'EL')" FLOAT,
# 	"('Adj Close', 'EMN')" FLOAT,
# 	"('Adj Close', 'EMR')" FLOAT,
# 	"('Adj Close', 'ENPH')" FLOAT,
# 	"('Adj Close', 'EOG')" FLOAT,
# 	"('Adj Close', 'EQIX')" FLOAT,
# 	"('Adj Close', 'EQR')" FLOAT,
# 	"('Adj Close', 'ES')" FLOAT,
# 	"('Adj Close', 'ESS')" FLOAT,
# 	"('Adj Close', 'ETN')" FLOAT,
# 	"('Adj Close', 'ETR')" FLOAT,
# 	"('Adj Close', 'ETSY')" FLOAT,
# 	"('Adj Close', 'EVRG')" FLOAT,
# 	"('Adj Close', 'EW')" FLOAT,
# 	"('Adj Close', 'EXC')" FLOAT,
# 	"('Adj Close', 'EXPD')" FLOAT,
# 	"('Adj Close', 'EXPE')" FLOAT,
# 	"('Adj Close', 'EXR')" FLOAT,
# 	"('Adj Close', 'F')" FLOAT,
# 	"('Adj Close', 'FANG')" FLOAT,
# 	"('Adj Close', 'FAST')" FLOAT,
# 	"('Adj Close', 'FB')" FLOAT,
# 	"('Adj Close', 'FBHS')" FLOAT,
# 	"('Adj Close', 'FCX')" FLOAT,
# 	"('Adj Close', 'FDX')" FLOAT,
# 	"('Adj Close', 'FE')" FLOAT,
# 	"('Adj Close', 'FFIV')" FLOAT,
# 	"('Adj Close', 'FIS')" FLOAT,
# 	"('Adj Close', 'FISV')" FLOAT,
# 	"('Adj Close', 'FITB')" FLOAT,
# 	"('Adj Close', 'FLT')" FLOAT,
# 	"('Adj Close', 'FMC')" FLOAT,
# 	"('Adj Close', 'FOX')" FLOAT,
# 	"('Adj Close', 'FOXA')" FLOAT,
# 	"('Adj Close', 'FRC')" FLOAT,
# 	"('Adj Close', 'FRT')" FLOAT,
# 	"('Adj Close', 'FTNT')" FLOAT,
# 	"('Adj Close', 'FTV')" FLOAT,
# 	"('Adj Close', 'GD')" FLOAT,
# 	"('Adj Close', 'GE')" FLOAT,
# 	"('Adj Close', 'GILD')" FLOAT,
# 	"('Adj Close', 'GIS')" FLOAT,
# 	"('Adj Close', 'GL')" FLOAT,
# 	"('Adj Close', 'GLW')" FLOAT,
# 	"('Adj Close', 'GM')" FLOAT,
# 	"('Adj Close', 'GNRC')" FLOAT,
# 	"('Adj Close', 'GOOG')" FLOAT,
# 	"('Adj Close', 'GOOGL')" FLOAT,
# 	"('Adj Close', 'GPC')" FLOAT,
# 	"('Adj Close', 'GPN')" FLOAT,
# 	"('Adj Close', 'GPS')" FLOAT,
# 	"('Adj Close', 'GRMN')" FLOAT,
# 	"('Adj Close', 'GS')" FLOAT,
# 	"('Adj Close', 'GWW')" FLOAT,
# 	"('Adj Close', 'HAL')" FLOAT,
# 	"('Adj Close', 'HAS')" FLOAT,
# 	"('Adj Close', 'HBAN')" FLOAT,
# 	"('Adj Close', 'HBI')" FLOAT,
# 	"('Adj Close', 'HCA')" FLOAT,
# 	"('Adj Close', 'HD')" FLOAT,
# 	"('Adj Close', 'HES')" FLOAT,
# 	"('Adj Close', 'HIG')" FLOAT,
# 	"('Adj Close', 'HII')" FLOAT,
# 	"('Adj Close', 'HLT')" FLOAT,
# 	"('Adj Close', 'HOLX')" FLOAT,
# 	"('Adj Close', 'HON')" FLOAT,
# 	"('Adj Close', 'HPE')" FLOAT,
# 	"('Adj Close', 'HPQ')" FLOAT,
# 	"('Adj Close', 'HRL')" FLOAT,
# 	"('Adj Close', 'HSIC')" FLOAT,
# 	"('Adj Close', 'HST')" FLOAT,
# 	"('Adj Close', 'HSY')" FLOAT,
# 	"('Adj Close', 'HUM')" FLOAT,
# 	"('Adj Close', 'HWM')" FLOAT,
# 	"('Adj Close', 'IBM')" FLOAT,
# 	"('Adj Close', 'ICE')" FLOAT,
# 	"('Adj Close', 'IDXX')" FLOAT,
# 	"('Adj Close', 'IEX')" FLOAT,
# 	"('Adj Close', 'IFF')" FLOAT,
# 	"('Adj Close', 'ILMN')" FLOAT,
# 	"('Adj Close', 'INCY')" FLOAT,
# 	"('Adj Close', 'INFO')" FLOAT,
# 	"('Adj Close', 'INTC')" FLOAT,
# 	"('Adj Close', 'INTU')" FLOAT,
# 	"('Adj Close', 'IP')" FLOAT,
# 	"('Adj Close', 'IPG')" FLOAT,
# 	"('Adj Close', 'IPGP')" FLOAT,
# 	"('Adj Close', 'IQV')" FLOAT,
# 	"('Adj Close', 'IR')" FLOAT,
# 	"('Adj Close', 'IRM')" FLOAT,
# 	"('Adj Close', 'ISRG')" FLOAT,
# 	"('Adj Close', 'IT')" FLOAT,
# 	"('Adj Close', 'ITW')" FLOAT,
# 	"('Adj Close', 'IVZ')" FLOAT,
# 	"('Adj Close', 'J')" FLOAT,
# 	"('Adj Close', 'JBHT')" FLOAT,
# 	"('Adj Close', 'JCI')" FLOAT,
# 	"('Adj Close', 'JKHY')" FLOAT,
# 	"('Adj Close', 'JNJ')" FLOAT,
# 	"('Adj Close', 'JNPR')" FLOAT,
# 	"('Adj Close', 'JPM')" FLOAT,
# 	"('Adj Close', 'K')" FLOAT,
# 	"('Adj Close', 'KEY')" FLOAT,
# 	"('Adj Close', 'KEYS')" FLOAT,
# 	"('Adj Close', 'KHC')" FLOAT,
# 	"('Adj Close', 'KIM')" FLOAT,
# 	"('Adj Close', 'KLAC')" FLOAT,
# 	"('Adj Close', 'KMB')" FLOAT,
# 	"('Adj Close', 'KMI')" FLOAT,
# 	"('Adj Close', 'KMX')" FLOAT,
# 	"('Adj Close', 'KO')" FLOAT,
# 	"('Adj Close', 'KR')" FLOAT,
# 	"('Adj Close', 'KSU')" FLOAT,
# 	"('Adj Close', 'L')" FLOAT,
# 	"('Adj Close', 'LDOS')" FLOAT,
# 	"('Adj Close', 'LEG')" FLOAT,
# 	"('Adj Close', 'LEN')" FLOAT,
# 	"('Adj Close', 'LH')" FLOAT,
# 	"('Adj Close', 'LHX')" FLOAT,
# 	"('Adj Close', 'LIN')" FLOAT,
# 	"('Adj Close', 'LKQ')" FLOAT,
# 	"('Adj Close', 'LLY')" FLOAT,
# 	"('Adj Close', 'LMT')" FLOAT,
# 	"('Adj Close', 'LNC')" FLOAT,
# 	"('Adj Close', 'LNT')" FLOAT,
# 	"('Adj Close', 'LOW')" FLOAT,
# 	"('Adj Close', 'LRCX')" FLOAT,
# 	"('Adj Close', 'LUMN')" FLOAT,
# 	"('Adj Close', 'LUV')" FLOAT,
# 	"('Adj Close', 'LVS')" FLOAT,
# 	"('Adj Close', 'LW')" FLOAT,
# 	"('Adj Close', 'LYB')" FLOAT,
# 	"('Adj Close', 'LYV')" FLOAT,
# 	"('Adj Close', 'MA')" FLOAT,
# 	"('Adj Close', 'MAA')" FLOAT,
# 	"('Adj Close', 'MAR')" FLOAT,
# 	"('Adj Close', 'MAS')" FLOAT,
# 	"('Adj Close', 'MCD')" FLOAT,
# 	"('Adj Close', 'MCHP')" FLOAT,
# 	"('Adj Close', 'MCK')" FLOAT,
# 	"('Adj Close', 'MCO')" FLOAT,
# 	"('Adj Close', 'MDLZ')" FLOAT,
# 	"('Adj Close', 'MDT')" FLOAT,
# 	"('Adj Close', 'MET')" FLOAT,
# 	"('Adj Close', 'MGM')" FLOAT,
# 	"('Adj Close', 'MHK')" FLOAT,
# 	"('Adj Close', 'MKC')" FLOAT,
# 	"('Adj Close', 'MKTX')" FLOAT,
# 	"('Adj Close', 'MLM')" FLOAT,
# 	"('Adj Close', 'MMC')" FLOAT,
# 	"('Adj Close', 'MMM')" FLOAT,
# 	"('Adj Close', 'MNST')" FLOAT,
# 	"('Adj Close', 'MO')" FLOAT,
# 	"('Adj Close', 'MOS')" FLOAT,
# 	"('Adj Close', 'MPC')" FLOAT,
# 	"('Adj Close', 'MPWR')" FLOAT,
# 	"('Adj Close', 'MRK')" FLOAT,
# 	"('Adj Close', 'MRNA')" FLOAT,
# 	"('Adj Close', 'MRO')" FLOAT,
# 	"('Adj Close', 'MS')" FLOAT,
# 	"('Adj Close', 'MSCI')" FLOAT,
# 	"('Adj Close', 'MSFT')" FLOAT,
# 	"('Adj Close', 'MSI')" FLOAT,
# 	"('Adj Close', 'MTB')" FLOAT,
# 	"('Adj Close', 'MTD')" FLOAT,
# 	"('Adj Close', 'MU')" FLOAT,
# 	"('Adj Close', 'MXIM')" FLOAT,
# 	"('Adj Close', 'NCLH')" FLOAT,
# 	"('Adj Close', 'NDAQ')" FLOAT,
# 	"('Adj Close', 'NEE')" FLOAT,
# 	"('Adj Close', 'NEM')" FLOAT,
# 	"('Adj Close', 'NFLX')" FLOAT,
# 	"('Adj Close', 'NI')" FLOAT,
# 	"('Adj Close', 'NKE')" FLOAT,
# 	"('Adj Close', 'NLOK')" FLOAT,
# 	"('Adj Close', 'NLSN')" FLOAT,
# 	"('Adj Close', 'NOC')" FLOAT,
# 	"('Adj Close', 'NOV')" FLOAT,
# 	"('Adj Close', 'NOW')" FLOAT,
# 	"('Adj Close', 'NRG')" FLOAT,
# 	"('Adj Close', 'NSC')" FLOAT,
# 	"('Adj Close', 'NTAP')" FLOAT,
# 	"('Adj Close', 'NTRS')" FLOAT,
# 	"('Adj Close', 'NUE')" FLOAT,
# 	"('Adj Close', 'NVDA')" FLOAT,
# 	"('Adj Close', 'NVR')" FLOAT,
# 	"('Adj Close', 'NWL')" FLOAT,
# 	"('Adj Close', 'NWS')" FLOAT,
# 	"('Adj Close', 'NWSA')" FLOAT,
# 	"('Adj Close', 'NXPI')" FLOAT,
# 	"('Adj Close', 'O')" FLOAT,
# 	"('Adj Close', 'ODFL')" FLOAT,
# 	"('Adj Close', 'OGN')" FLOAT,
# 	"('Adj Close', 'OKE')" FLOAT,
# 	"('Adj Close', 'OMC')" FLOAT,
# 	"('Adj Close', 'ORCL')" FLOAT,
# 	"('Adj Close', 'ORLY')" FLOAT,
# 	"('Adj Close', 'OTIS')" FLOAT,
# 	"('Adj Close', 'OXY')" FLOAT,
# 	"('Adj Close', 'PAYC')" FLOAT,
# 	"('Adj Close', 'PAYX')" FLOAT,
# 	"('Adj Close', 'PBCT')" FLOAT,
# 	"('Adj Close', 'PCAR')" FLOAT,
# 	"('Adj Close', 'PEAK')" FLOAT,
# 	"('Adj Close', 'PEG')" FLOAT,
# 	"('Adj Close', 'PENN')" FLOAT,
# 	"('Adj Close', 'PEP')" FLOAT,
# 	"('Adj Close', 'PFE')" FLOAT,
# 	"('Adj Close', 'PFG')" FLOAT,
# 	"('Adj Close', 'PG')" FLOAT,
# 	"('Adj Close', 'PGR')" FLOAT,
# 	"('Adj Close', 'PH')" FLOAT,
# 	"('Adj Close', 'PHM')" FLOAT,
# 	"('Adj Close', 'PKG')" FLOAT,
# 	"('Adj Close', 'PKI')" FLOAT,
# 	"('Adj Close', 'PLD')" FLOAT,
# 	"('Adj Close', 'PM')" FLOAT,
# 	"('Adj Close', 'PNC')" FLOAT,
# 	"('Adj Close', 'PNR')" FLOAT,
# 	"('Adj Close', 'PNW')" FLOAT,
# 	"('Adj Close', 'POOL')" FLOAT,
# 	"('Adj Close', 'PPG')" FLOAT,
# 	"('Adj Close', 'PPL')" FLOAT,
# 	"('Adj Close', 'PRGO')" FLOAT,
# 	"('Adj Close', 'PRU')" FLOAT,
# 	"('Adj Close', 'PSA')" FLOAT,
# 	"('Adj Close', 'PSX')" FLOAT,
# 	"('Adj Close', 'PTC')" FLOAT,
# 	"('Adj Close', 'PVH')" FLOAT,
# 	"('Adj Close', 'PWR')" FLOAT,
# 	"('Adj Close', 'PXD')" FLOAT,
# 	"('Adj Close', 'PYPL')" FLOAT,
# 	"('Adj Close', 'QCOM')" FLOAT,
# 	"('Adj Close', 'QRVO')" FLOAT,
# 	"('Adj Close', 'RCL')" FLOAT,
# 	"('Adj Close', 'RE')" FLOAT,
# 	"('Adj Close', 'REG')" FLOAT,
# 	"('Adj Close', 'REGN')" FLOAT,
# 	"('Adj Close', 'RF')" FLOAT,
# 	"('Adj Close', 'RHI')" FLOAT,
# 	"('Adj Close', 'RJF')" FLOAT,
# 	"('Adj Close', 'RL')" FLOAT,
# 	"('Adj Close', 'RMD')" FLOAT,
# 	"('Adj Close', 'ROK')" FLOAT,
# 	"('Adj Close', 'ROL')" FLOAT,
# 	"('Adj Close', 'ROP')" FLOAT,
# 	"('Adj Close', 'ROST')" FLOAT,
# 	"('Adj Close', 'RSG')" FLOAT,
# 	"('Adj Close', 'RTX')" FLOAT,
# 	"('Adj Close', 'SBAC')" FLOAT,
# 	"('Adj Close', 'SBUX')" FLOAT,
# 	"('Adj Close', 'SCHW')" FLOAT,
# 	"('Adj Close', 'SEE')" FLOAT,
# 	"('Adj Close', 'SHW')" FLOAT,
# 	"('Adj Close', 'SIVB')" FLOAT,
# 	"('Adj Close', 'SJM')" FLOAT,
# 	"('Adj Close', 'SLB')" FLOAT,
# 	"('Adj Close', 'SNA')" FLOAT,
# 	"('Adj Close', 'SNPS')" FLOAT,
# 	"('Adj Close', 'SO')" FLOAT,
# 	"('Adj Close', 'SPG')" FLOAT,
# 	"('Adj Close', 'SPGI')" FLOAT,
# 	"('Adj Close', 'SRE')" FLOAT,
# 	"('Adj Close', 'STE')" FLOAT,
# 	"('Adj Close', 'STT')" FLOAT,
# 	"('Adj Close', 'STX')" FLOAT,
# 	"('Adj Close', 'STZ')" FLOAT,
# 	"('Adj Close', 'SWK')" FLOAT,
# 	"('Adj Close', 'SWKS')" FLOAT,
# 	"('Adj Close', 'SYF')" FLOAT,
# 	"('Adj Close', 'SYK')" FLOAT,
# 	"('Adj Close', 'SYY')" FLOAT,
# 	"('Adj Close', 'T')" FLOAT,
# 	"('Adj Close', 'TAP')" FLOAT,
# 	"('Adj Close', 'TDG')" FLOAT,
# 	"('Adj Close', 'TDY')" FLOAT,
# 	"('Adj Close', 'TEL')" FLOAT,
# 	"('Adj Close', 'TER')" FLOAT,
# 	"('Adj Close', 'TFC')" FLOAT,
# 	"('Adj Close', 'TFX')" FLOAT,
# 	"('Adj Close', 'TGT')" FLOAT,
# 	"('Adj Close', 'TJX')" FLOAT,
# 	"('Adj Close', 'TMO')" FLOAT,
# 	"('Adj Close', 'TMUS')" FLOAT,
# 	"('Adj Close', 'TPR')" FLOAT,
# 	"('Adj Close', 'TRMB')" FLOAT,
# 	"('Adj Close', 'TROW')" FLOAT,
# 	"('Adj Close', 'TRV')" FLOAT,
# 	"('Adj Close', 'TSCO')" FLOAT,
# 	"('Adj Close', 'TSLA')" FLOAT,
# 	"('Adj Close', 'TSN')" FLOAT,
# 	"('Adj Close', 'TT')" FLOAT,
# 	"('Adj Close', 'TTWO')" FLOAT,
# 	"('Adj Close', 'TWTR')" FLOAT,
# 	"('Adj Close', 'TXN')" FLOAT,
# 	"('Adj Close', 'TXT')" FLOAT,
# 	"('Adj Close', 'TYL')" FLOAT,
# 	"('Adj Close', 'UA')" FLOAT,
# 	"('Adj Close', 'UAA')" FLOAT,
# 	"('Adj Close', 'UAL')" FLOAT,
# 	"('Adj Close', 'UDR')" FLOAT,
# 	"('Adj Close', 'UHS')" FLOAT,
# 	"('Adj Close', 'ULTA')" FLOAT,
# 	"('Adj Close', 'UNH')" FLOAT,
# 	"('Adj Close', 'UNM')" FLOAT,
# 	"('Adj Close', 'UNP')" FLOAT,
# 	"('Adj Close', 'UPS')" FLOAT,
# 	"('Adj Close', 'URI')" FLOAT,
# 	"('Adj Close', 'USB')" FLOAT,
# 	"('Adj Close', 'V')" FLOAT,
# 	"('Adj Close', 'VFC')" FLOAT,
# 	"('Adj Close', 'VIAC')" FLOAT,
# 	"('Adj Close', 'VLO')" FLOAT,
# 	"('Adj Close', 'VMC')" FLOAT,
# 	"('Adj Close', 'VNO')" FLOAT,
# 	"('Adj Close', 'VRSK')" FLOAT,
# 	"('Adj Close', 'VRSN')" FLOAT,
# 	"('Adj Close', 'VRTX')" FLOAT,
# 	"('Adj Close', 'VTR')" FLOAT,
# 	"('Adj Close', 'VTRS')" FLOAT,
# 	"('Adj Close', 'VZ')" FLOAT,
# 	"('Adj Close', 'WAB')" FLOAT,
# 	"('Adj Close', 'WAT')" FLOAT,
# 	"('Adj Close', 'WBA')" FLOAT,
# 	"('Adj Close', 'WDC')" FLOAT,
# 	"('Adj Close', 'WEC')" FLOAT,
# 	"('Adj Close', 'WELL')" FLOAT,
# 	"('Adj Close', 'WFC')" FLOAT,
# 	"('Adj Close', 'WHR')" FLOAT,
# 	"('Adj Close', 'WLTW')" FLOAT,
# 	"('Adj Close', 'WM')" FLOAT,
# 	"('Adj Close', 'WMB')" FLOAT,
# 	"('Adj Close', 'WMT')" FLOAT,
# 	"('Adj Close', 'WRB')" FLOAT,
# 	"('Adj Close', 'WRK')" FLOAT,
# 	"('Adj Close', 'WST')" FLOAT,
# 	"('Adj Close', 'WU')" FLOAT,
# 	"('Adj Close', 'WY')" FLOAT,
# 	"('Adj Close', 'WYNN')" FLOAT,
# 	"('Adj Close', 'XEL')" FLOAT,
# 	"('Adj Close', 'XLNX')" FLOAT,
# 	"('Adj Close', 'XOM')" FLOAT,
# 	"('Adj Close', 'XRAY')" FLOAT,
# 	"('Adj Close', 'XYL')" FLOAT,
# 	"('Adj Close', 'YUM')" FLOAT,
# 	"('Adj Close', 'ZBH')" FLOAT,
# 	"('Adj Close', 'ZBRA')" FLOAT,
# 	"('Adj Close', 'ZION')" FLOAT,
# 	"('Adj Close', 'ZTS')" FLOAT,
# 	"('Close', 'A')" FLOAT,
# 	"('Close', 'AAL')" FLOAT,
# 	"('Close', 'AAP')" FLOAT,
# 	"('Close', 'AAPL')" FLOAT,
# 	"('Close', 'ABBV')" FLOAT,
# 	"('Close', 'ABC')" FLOAT,
# 	"('Close', 'ABMD')" FLOAT,
# 	"('Close', 'ABT')" FLOAT,
# 	"('Close', 'ACN')" FLOAT,
# 	"('Close', 'ADBE')" FLOAT,
# 	"('Close', 'ADI')" FLOAT,
# 	"('Close', 'ADM')" FLOAT,
# 	"('Close', 'ADP')" FLOAT,
# 	"('Close', 'ADSK')" FLOAT,
# 	"('Close', 'AEE')" FLOAT,
# 	"('Close', 'AEP')" FLOAT,
# 	"('Close', 'AES')" FLOAT,
# 	"('Close', 'AFL')" FLOAT,
# 	"('Close', 'AIG')" FLOAT,
# 	"('Close', 'AIZ')" FLOAT,
# 	"('Close', 'AJG')" FLOAT,
# 	"('Close', 'AKAM')" FLOAT,
# 	"('Close', 'ALB')" FLOAT,
# 	"('Close', 'ALGN')" FLOAT,
# 	"('Close', 'ALK')" FLOAT,
# 	"('Close', 'ALL')" FLOAT,
# 	"('Close', 'ALLE')" FLOAT,
# 	"('Close', 'AMAT')" FLOAT,
# 	"('Close', 'AMCR')" FLOAT,
# 	"('Close', 'AMD')" FLOAT,
# 	"('Close', 'AME')" FLOAT,
# 	"('Close', 'AMGN')" FLOAT,
# 	"('Close', 'AMP')" FLOAT,
# 	"('Close', 'AMT')" FLOAT,
# 	"('Close', 'AMZN')" FLOAT,
# 	"('Close', 'ANET')" FLOAT,
# 	"('Close', 'ANSS')" FLOAT,
# 	"('Close', 'ANTM')" FLOAT,
# 	"('Close', 'AON')" FLOAT,
# 	"('Close', 'AOS')" FLOAT,
# 	"('Close', 'APA')" FLOAT,
# 	"('Close', 'APD')" FLOAT,
# 	"('Close', 'APH')" FLOAT,
# 	"('Close', 'APTV')" FLOAT,
# 	"('Close', 'ARE')" FLOAT,
# 	"('Close', 'ATO')" FLOAT,
# 	"('Close', 'ATVI')" FLOAT,
# 	"('Close', 'AVB')" FLOAT,
# 	"('Close', 'AVGO')" FLOAT,
# 	"('Close', 'AVY')" FLOAT,
# 	"('Close', 'AWK')" FLOAT,
# 	"('Close', 'AXP')" FLOAT,
# 	"('Close', 'AZO')" FLOAT,
# 	"('Close', 'BA')" FLOAT,
# 	"('Close', 'BAC')" FLOAT,
# 	"('Close', 'BAX')" FLOAT,
# 	"('Close', 'BBWI')" FLOAT,
# 	"('Close', 'BBY')" FLOAT,
# 	"('Close', 'BDX')" FLOAT,
# 	"('Close', 'BEN')" FLOAT,
# 	"('Close', 'BF-B')" FLOAT,
# 	"('Close', 'BIIB')" FLOAT,
# 	"('Close', 'BIO')" FLOAT,
# 	"('Close', 'BK')" FLOAT,
# 	"('Close', 'BKNG')" FLOAT,
# 	"('Close', 'BKR')" FLOAT,
# 	"('Close', 'BLK')" FLOAT,
# 	"('Close', 'BLL')" FLOAT,
# 	"('Close', 'BMY')" FLOAT,
# 	"('Close', 'BR')" FLOAT,
# 	"('Close', 'BRK-B')" FLOAT,
# 	"('Close', 'BSX')" FLOAT,
# 	"('Close', 'BWA')" FLOAT,
# 	"('Close', 'BXP')" FLOAT,
# 	"('Close', 'C')" FLOAT,
# 	"('Close', 'CAG')" FLOAT,
# 	"('Close', 'CAH')" FLOAT,
# 	"('Close', 'CARR')" FLOAT,
# 	"('Close', 'CAT')" FLOAT,
# 	"('Close', 'CB')" FLOAT,
# 	"('Close', 'CBOE')" FLOAT,
# 	"('Close', 'CBRE')" FLOAT,
# 	"('Close', 'CCI')" FLOAT,
# 	"('Close', 'CCL')" FLOAT,
# 	"('Close', 'CDNS')" FLOAT,
# 	"('Close', 'CDW')" FLOAT,
# 	"('Close', 'CE')" FLOAT,
# 	"('Close', 'CERN')" FLOAT,
# 	"('Close', 'CF')" FLOAT,
# 	"('Close', 'CFG')" FLOAT,
# 	"('Close', 'CHD')" FLOAT,
# 	"('Close', 'CHRW')" FLOAT,
# 	"('Close', 'CHTR')" FLOAT,
# 	"('Close', 'CI')" FLOAT,
# 	"('Close', 'CINF')" FLOAT,
# 	"('Close', 'CL')" FLOAT,
# 	"('Close', 'CLX')" FLOAT,
# 	"('Close', 'CMA')" FLOAT,
# 	"('Close', 'CMCSA')" FLOAT,
# 	"('Close', 'CME')" FLOAT,
# 	"('Close', 'CMG')" FLOAT,
# 	"('Close', 'CMI')" FLOAT,
# 	"('Close', 'CMS')" FLOAT,
# 	"('Close', 'CNC')" FLOAT,
# 	"('Close', 'CNP')" FLOAT,
# 	"('Close', 'COF')" FLOAT,
# 	"('Close', 'COG')" FLOAT,
# 	"('Close', 'COO')" FLOAT,
# 	"('Close', 'COP')" FLOAT,
# 	"('Close', 'COST')" FLOAT,
# 	"('Close', 'CPB')" FLOAT,
# 	"('Close', 'CPRT')" FLOAT,
# 	"('Close', 'CRL')" FLOAT,
# 	"('Close', 'CRM')" FLOAT,
# 	"('Close', 'CSCO')" FLOAT,
# 	"('Close', 'CSX')" FLOAT,
# 	"('Close', 'CTAS')" FLOAT,
# 	"('Close', 'CTLT')" FLOAT,
# 	"('Close', 'CTSH')" FLOAT,
# 	"('Close', 'CTVA')" FLOAT,
# 	"('Close', 'CTXS')" FLOAT,
# 	"('Close', 'CVS')" FLOAT,
# 	"('Close', 'CVX')" FLOAT,
# 	"('Close', 'CZR')" FLOAT,
# 	"('Close', 'D')" FLOAT,
# 	"('Close', 'DAL')" FLOAT,
# 	"('Close', 'DD')" FLOAT,
# 	"('Close', 'DE')" FLOAT,
# 	"('Close', 'DFS')" FLOAT,
# 	"('Close', 'DG')" FLOAT,
# 	"('Close', 'DGX')" FLOAT,
# 	"('Close', 'DHI')" FLOAT,
# 	"('Close', 'DHR')" FLOAT,
# 	"('Close', 'DIS')" FLOAT,
# 	"('Close', 'DISCA')" FLOAT,
# 	"('Close', 'DISCK')" FLOAT,
# 	"('Close', 'DISH')" FLOAT,
# 	"('Close', 'DLR')" FLOAT,
# 	"('Close', 'DLTR')" FLOAT,
# 	"('Close', 'DOV')" FLOAT,
# 	"('Close', 'DOW')" FLOAT,
# 	"('Close', 'DPZ')" FLOAT,
# 	"('Close', 'DRE')" FLOAT,
# 	"('Close', 'DRI')" FLOAT,
# 	"('Close', 'DTE')" FLOAT,
# 	"('Close', 'DUK')" FLOAT,
# 	"('Close', 'DVA')" FLOAT,
# 	"('Close', 'DVN')" FLOAT,
# 	"('Close', 'DXC')" FLOAT,
# 	"('Close', 'DXCM')" FLOAT,
# 	"('Close', 'EA')" FLOAT,
# 	"('Close', 'EBAY')" FLOAT,
# 	"('Close', 'ECL')" FLOAT,
# 	"('Close', 'ED')" FLOAT,
# 	"('Close', 'EFX')" FLOAT,
# 	"('Close', 'EIX')" FLOAT,
# 	"('Close', 'EL')" FLOAT,
# 	"('Close', 'EMN')" FLOAT,
# 	"('Close', 'EMR')" FLOAT,
# 	"('Close', 'ENPH')" FLOAT,
# 	"('Close', 'EOG')" FLOAT,
# 	"('Close', 'EQIX')" FLOAT,
# 	"('Close', 'EQR')" FLOAT,
# 	"('Close', 'ES')" FLOAT,
# 	"('Close', 'ESS')" FLOAT,
# 	"('Close', 'ETN')" FLOAT,
# 	"('Close', 'ETR')" FLOAT,
# 	"('Close', 'ETSY')" FLOAT,
# 	"('Close', 'EVRG')" FLOAT,
# 	"('Close', 'EW')" FLOAT,
# 	"('Close', 'EXC')" FLOAT,
# 	"('Close', 'EXPD')" FLOAT,
# 	"('Close', 'EXPE')" FLOAT,
# 	"('Close', 'EXR')" FLOAT,
# 	"('Close', 'F')" FLOAT,
# 	"('Close', 'FANG')" FLOAT,
# 	"('Close', 'FAST')" FLOAT,
# 	"('Close', 'FB')" FLOAT,
# 	"('Close', 'FBHS')" FLOAT,
# 	"('Close', 'FCX')" FLOAT,
# 	"('Close', 'FDX')" FLOAT,
# 	"('Close', 'FE')" FLOAT,
# 	"('Close', 'FFIV')" FLOAT,
# 	"('Close', 'FIS')" FLOAT,
# 	"('Close', 'FISV')" FLOAT,
# 	"('Close', 'FITB')" FLOAT,
# 	"('Close', 'FLT')" FLOAT,
# 	"('Close', 'FMC')" FLOAT,
# 	"('Close', 'FOX')" FLOAT,
# 	"('Close', 'FOXA')" FLOAT,
# 	"('Close', 'FRC')" FLOAT,
# 	"('Close', 'FRT')" FLOAT,
# 	"('Close', 'FTNT')" FLOAT,
# 	"('Close', 'FTV')" FLOAT,
# 	"('Close', 'GD')" FLOAT,
# 	"('Close', 'GE')" FLOAT,
# 	"('Close', 'GILD')" FLOAT,
# 	"('Close', 'GIS')" FLOAT,
# 	"('Close', 'GL')" FLOAT,
# 	"('Close', 'GLW')" FLOAT,
# 	"('Close', 'GM')" FLOAT,
# 	"('Close', 'GNRC')" FLOAT,
# 	"('Close', 'GOOG')" FLOAT,
# 	"('Close', 'GOOGL')" FLOAT,
# 	"('Close', 'GPC')" FLOAT,
# 	"('Close', 'GPN')" FLOAT,
# 	"('Close', 'GPS')" FLOAT,
# 	"('Close', 'GRMN')" FLOAT,
# 	"('Close', 'GS')" FLOAT,
# 	"('Close', 'GWW')" FLOAT,
# 	"('Close', 'HAL')" FLOAT,
# 	"('Close', 'HAS')" FLOAT,
# 	"('Close', 'HBAN')" FLOAT,
# 	"('Close', 'HBI')" FLOAT,
# 	"('Close', 'HCA')" FLOAT,
# 	"('Close', 'HD')" FLOAT,
# 	"('Close', 'HES')" FLOAT,
# 	"('Close', 'HIG')" FLOAT,
# 	"('Close', 'HII')" FLOAT,
# 	"('Close', 'HLT')" FLOAT,
# 	"('Close', 'HOLX')" FLOAT,
# 	"('Close', 'HON')" FLOAT,
# 	"('Close', 'HPE')" FLOAT,
# 	"('Close', 'HPQ')" FLOAT,
# 	"('Close', 'HRL')" FLOAT,
# 	"('Close', 'HSIC')" FLOAT,
# 	"('Close', 'HST')" FLOAT,
# 	"('Close', 'HSY')" FLOAT,
# 	"('Close', 'HUM')" FLOAT,
# 	"('Close', 'HWM')" FLOAT,
# 	"('Close', 'IBM')" FLOAT,
# 	"('Close', 'ICE')" FLOAT,
# 	"('Close', 'IDXX')" FLOAT,
# 	"('Close', 'IEX')" FLOAT,
# 	"('Close', 'IFF')" FLOAT,
# 	"('Close', 'ILMN')" FLOAT,
# 	"('Close', 'INCY')" FLOAT,
# 	"('Close', 'INFO')" FLOAT,
# 	"('Close', 'INTC')" FLOAT,
# 	"('Close', 'INTU')" FLOAT,
# 	"('Close', 'IP')" FLOAT,
# 	"('Close', 'IPG')" FLOAT,
# 	"('Close', 'IPGP')" FLOAT,
# 	"('Close', 'IQV')" FLOAT,
# 	"('Close', 'IR')" FLOAT,
# 	"('Close', 'IRM')" FLOAT,
# 	"('Close', 'ISRG')" FLOAT,
# 	"('Close', 'IT')" FLOAT,
# 	"('Close', 'ITW')" FLOAT,
# 	"('Close', 'IVZ')" FLOAT,
# 	"('Close', 'J')" FLOAT,
# 	"('Close', 'JBHT')" FLOAT,
# 	"('Close', 'JCI')" FLOAT,
# 	"('Close', 'JKHY')" FLOAT,
# 	"('Close', 'JNJ')" FLOAT,
# 	"('Close', 'JNPR')" FLOAT,
# 	"('Close', 'JPM')" FLOAT,
# 	"('Close', 'K')" FLOAT,
# 	"('Close', 'KEY')" FLOAT,
# 	"('Close', 'KEYS')" FLOAT,
# 	"('Close', 'KHC')" FLOAT,
# 	"('Close', 'KIM')" FLOAT,
# 	"('Close', 'KLAC')" FLOAT,
# 	"('Close', 'KMB')" FLOAT,
# 	"('Close', 'KMI')" FLOAT,
# 	"('Close', 'KMX')" FLOAT,
# 	"('Close', 'KO')" FLOAT,
# 	"('Close', 'KR')" FLOAT,
# 	"('Close', 'KSU')" FLOAT,
# 	"('Close', 'L')" FLOAT,
# 	"('Close', 'LDOS')" FLOAT,
# 	"('Close', 'LEG')" FLOAT,
# 	"('Close', 'LEN')" FLOAT,
# 	"('Close', 'LH')" FLOAT,
# 	"('Close', 'LHX')" FLOAT,
# 	"('Close', 'LIN')" FLOAT,
# 	"('Close', 'LKQ')" FLOAT,
# 	"('Close', 'LLY')" FLOAT,
# 	"('Close', 'LMT')" FLOAT,
# 	"('Close', 'LNC')" FLOAT,
# 	"('Close', 'LNT')" FLOAT,
# 	"('Close', 'LOW')" FLOAT,
# 	"('Close', 'LRCX')" FLOAT,
# 	"('Close', 'LUMN')" FLOAT,
# 	"('Close', 'LUV')" FLOAT,
# 	"('Close', 'LVS')" FLOAT,
# 	"('Close', 'LW')" FLOAT,
# 	"('Close', 'LYB')" FLOAT,
# 	"('Close', 'LYV')" FLOAT,
# 	"('Close', 'MA')" FLOAT,
# 	"('Close', 'MAA')" FLOAT,
# 	"('Close', 'MAR')" FLOAT,
# 	"('Close', 'MAS')" FLOAT,
# 	"('Close', 'MCD')" FLOAT,
# 	"('Close', 'MCHP')" FLOAT,
# 	"('Close', 'MCK')" FLOAT,
# 	"('Close', 'MCO')" FLOAT,
# 	"('Close', 'MDLZ')" FLOAT,
# 	"('Close', 'MDT')" FLOAT,
# 	"('Close', 'MET')" FLOAT,
# 	"('Close', 'MGM')" FLOAT,
# 	"('Close', 'MHK')" FLOAT,
# 	"('Close', 'MKC')" FLOAT,
# 	"('Close', 'MKTX')" FLOAT,
# 	"('Close', 'MLM')" FLOAT,
# 	"('Close', 'MMC')" FLOAT,
# 	"('Close', 'MMM')" FLOAT,
# 	"('Close', 'MNST')" FLOAT,
# 	"('Close', 'MO')" FLOAT,
# 	"('Close', 'MOS')" FLOAT,
# 	"('Close', 'MPC')" FLOAT,
# 	"('Close', 'MPWR')" FLOAT,
# 	"('Close', 'MRK')" FLOAT,
# 	"('Close', 'MRNA')" FLOAT,
# 	"('Close', 'MRO')" FLOAT,
# 	"('Close', 'MS')" FLOAT,
# 	"('Close', 'MSCI')" FLOAT,
# 	"('Close', 'MSFT')" FLOAT,
# 	"('Close', 'MSI')" FLOAT,
# 	"('Close', 'MTB')" FLOAT,
# 	"('Close', 'MTD')" FLOAT,
# 	"('Close', 'MU')" FLOAT,
# 	"('Close', 'MXIM')" FLOAT,
# 	"('Close', 'NCLH')" FLOAT,
# 	"('Close', 'NDAQ')" FLOAT,
# 	"('Close', 'NEE')" FLOAT,
# 	"('Close', 'NEM')" FLOAT,
# 	"('Close', 'NFLX')" FLOAT,
# 	"('Close', 'NI')" FLOAT,
# 	"('Close', 'NKE')" FLOAT,
# 	"('Close', 'NLOK')" FLOAT,
# 	"('Close', 'NLSN')" FLOAT,
# 	"('Close', 'NOC')" FLOAT,
# 	"('Close', 'NOV')" FLOAT,
# 	"('Close', 'NOW')" FLOAT,
# 	"('Close', 'NRG')" FLOAT,
# 	"('Close', 'NSC')" FLOAT,
# 	"('Close', 'NTAP')" FLOAT,
# 	"('Close', 'NTRS')" FLOAT,
# 	"('Close', 'NUE')" FLOAT,
# 	"('Close', 'NVDA')" FLOAT,
# 	"('Close', 'NVR')" FLOAT,
# 	"('Close', 'NWL')" FLOAT,
# 	"('Close', 'NWS')" FLOAT,
# 	"('Close', 'NWSA')" FLOAT,
# 	"('Close', 'NXPI')" FLOAT,
# 	"('Close', 'O')" FLOAT,
# 	"('Close', 'ODFL')" FLOAT,
# 	"('Close', 'OGN')" FLOAT,
# 	"('Close', 'OKE')" FLOAT,
# 	"('Close', 'OMC')" FLOAT,
# 	"('Close', 'ORCL')" FLOAT,
# 	"('Close', 'ORLY')" FLOAT,
# 	"('Close', 'OTIS')" FLOAT,
# 	"('Close', 'OXY')" FLOAT,
# 	"('Close', 'PAYC')" FLOAT,
# 	"('Close', 'PAYX')" FLOAT,
# 	"('Close', 'PBCT')" FLOAT,
# 	"('Close', 'PCAR')" FLOAT,
# 	"('Close', 'PEAK')" FLOAT,
# 	"('Close', 'PEG')" FLOAT,
# 	"('Close', 'PENN')" FLOAT,
# 	"('Close', 'PEP')" FLOAT,
# 	"('Close', 'PFE')" FLOAT,
# 	"('Close', 'PFG')" FLOAT,
# 	"('Close', 'PG')" FLOAT,
# 	"('Close', 'PGR')" FLOAT,
# 	"('Close', 'PH')" FLOAT,
# 	"('Close', 'PHM')" FLOAT,
# 	"('Close', 'PKG')" FLOAT,
# 	"('Close', 'PKI')" FLOAT,
# 	"('Close', 'PLD')" FLOAT,
# 	"('Close', 'PM')" FLOAT,
# 	"('Close', 'PNC')" FLOAT,
# 	"('Close', 'PNR')" FLOAT,
# 	"('Close', 'PNW')" FLOAT,
# 	"('Close', 'POOL')" FLOAT,
# 	"('Close', 'PPG')" FLOAT,
# 	"('Close', 'PPL')" FLOAT,
# 	"('Close', 'PRGO')" FLOAT,
# 	"('Close', 'PRU')" FLOAT,
# 	"('Close', 'PSA')" FLOAT,
# 	"('Close', 'PSX')" FLOAT,
# 	"('Close', 'PTC')" FLOAT,
# 	"('Close', 'PVH')" FLOAT,
# 	"('Close', 'PWR')" FLOAT,
# 	"('Close', 'PXD')" FLOAT,
# 	"('Close', 'PYPL')" FLOAT,
# 	"('Close', 'QCOM')" FLOAT,
# 	"('Close', 'QRVO')" FLOAT,
# 	"('Close', 'RCL')" FLOAT,
# 	"('Close', 'RE')" FLOAT,
# 	"('Close', 'REG')" FLOAT,
# 	"('Close', 'REGN')" FLOAT,
# 	"('Close', 'RF')" FLOAT,
# 	"('Close', 'RHI')" FLOAT,
# 	"('Close', 'RJF')" FLOAT,
# 	"('Close', 'RL')" FLOAT,
# 	"('Close', 'RMD')" FLOAT,
# 	"('Close', 'ROK')" FLOAT,
# 	"('Close', 'ROL')" FLOAT,
# 	"('Close', 'ROP')" FLOAT,
# 	"('Close', 'ROST')" FLOAT,
# 	"('Close', 'RSG')" FLOAT,
# 	"('Close', 'RTX')" FLOAT,
# 	"('Close', 'SBAC')" FLOAT,
# 	"('Close', 'SBUX')" FLOAT,
# 	"('Close', 'SCHW')" FLOAT,
# 	"('Close', 'SEE')" FLOAT,
# 	"('Close', 'SHW')" FLOAT,
# 	"('Close', 'SIVB')" FLOAT,
# 	"('Close', 'SJM')" FLOAT,
# 	"('Close', 'SLB')" FLOAT,
# 	"('Close', 'SNA')" FLOAT,
# 	"('Close', 'SNPS')" FLOAT,
# 	"('Close', 'SO')" FLOAT,
# 	"('Close', 'SPG')" FLOAT,
# 	"('Close', 'SPGI')" FLOAT,
# 	"('Close', 'SRE')" FLOAT,
# 	"('Close', 'STE')" FLOAT,
# 	"('Close', 'STT')" FLOAT,
# 	"('Close', 'STX')" FLOAT,
# 	"('Close', 'STZ')" FLOAT,
# 	"('Close', 'SWK')" FLOAT,
# 	"('Close', 'SWKS')" FLOAT,
# 	"('Close', 'SYF')" FLOAT,
# 	"('Close', 'SYK')" FLOAT,
# 	"('Close', 'SYY')" FLOAT,
# 	"('Close', 'T')" FLOAT,
# 	"('Close', 'TAP')" FLOAT,
# 	"('Close', 'TDG')" FLOAT,
# 	"('Close', 'TDY')" FLOAT,
# 	"('Close', 'TEL')" FLOAT,
# 	"('Close', 'TER')" FLOAT,
# 	"('Close', 'TFC')" FLOAT,
# 	"('Close', 'TFX')" FLOAT,
# 	"('Close', 'TGT')" FLOAT,
# 	"('Close', 'TJX')" FLOAT,
# 	"('Close', 'TMO')" FLOAT,
# 	"('Close', 'TMUS')" FLOAT,
# 	"('Close', 'TPR')" FLOAT,
# 	"('Close', 'TRMB')" FLOAT,
# 	"('Close', 'TROW')" FLOAT,
# 	"('Close', 'TRV')" FLOAT,
# 	"('Close', 'TSCO')" FLOAT,
# 	"('Close', 'TSLA')" FLOAT,
# 	"('Close', 'TSN')" FLOAT,
# 	"('Close', 'TT')" FLOAT,
# 	"('Close', 'TTWO')" FLOAT,
# 	"('Close', 'TWTR')" FLOAT,
# 	"('Close', 'TXN')" FLOAT,
# 	"('Close', 'TXT')" FLOAT,
# 	"('Close', 'TYL')" FLOAT,
# 	"('Close', 'UA')" FLOAT,
# 	"('Close', 'UAA')" FLOAT,
# 	"('Close', 'UAL')" FLOAT,
# 	"('Close', 'UDR')" FLOAT,
# 	"('Close', 'UHS')" FLOAT,
# 	"('Close', 'ULTA')" FLOAT,
# 	"('Close', 'UNH')" FLOAT,
# 	"('Close', 'UNM')" FLOAT,
# 	"('Close', 'UNP')" FLOAT,
# 	"('Close', 'UPS')" FLOAT,
# 	"('Close', 'URI')" FLOAT,
# 	"('Close', 'USB')" FLOAT,
# 	"('Close', 'V')" FLOAT,
# 	"('Close', 'VFC')" FLOAT,
# 	"('Close', 'VIAC')" FLOAT,
# 	"('Close', 'VLO')" FLOAT,
# 	"('Close', 'VMC')" FLOAT,
# 	"('Close', 'VNO')" FLOAT,
# 	"('Close', 'VRSK')" FLOAT,
# 	"('Close', 'VRSN')" FLOAT,
# 	"('Close', 'VRTX')" FLOAT,
# 	"('Close', 'VTR')" FLOAT,
# 	"('Close', 'VTRS')" FLOAT,
# 	"('Close', 'VZ')" FLOAT,
# 	"('Close', 'WAB')" FLOAT,
# 	"('Close', 'WAT')" FLOAT,
# 	"('Close', 'WBA')" FLOAT,
# 	"('Close', 'WDC')" FLOAT,
# 	"('Close', 'WEC')" FLOAT,
# 	"('Close', 'WELL')" FLOAT,
# 	"('Close', 'WFC')" FLOAT,
# 	"('Close', 'WHR')" FLOAT,
# 	"('Close', 'WLTW')" FLOAT,
# 	"('Close', 'WM')" FLOAT,
# 	"('Close', 'WMB')" FLOAT,
# 	"('Close', 'WMT')" FLOAT,
# 	"('Close', 'WRB')" FLOAT,
# 	"('Close', 'WRK')" FLOAT,
# 	"('Close', 'WST')" FLOAT,
# 	"('Close', 'WU')" FLOAT,
# 	"('Close', 'WY')" FLOAT,
# 	"('Close', 'WYNN')" FLOAT,
# 	"('Close', 'XEL')" FLOAT,
# 	"('Close', 'XLNX')" FLOAT,
# 	"('Close', 'XOM')" FLOAT,
# 	"('Close', 'XRAY')" FLOAT,
# 	"('Close', 'XYL')" FLOAT,
# 	"('Close', 'YUM')" FLOAT,
# 	"('Close', 'ZBH')" FLOAT,
# 	"('Close', 'ZBRA')" FLOAT,
# 	"('Close', 'ZION')" FLOAT,
# 	"('Close', 'ZTS')" FLOAT,
# 	"('High', 'A')" FLOAT,
# 	"('High', 'AAL')" FLOAT,
# 	"('High', 'AAP')" FLOAT,
# 	"('High', 'AAPL')" FLOAT,
# 	"('High', 'ABBV')" FLOAT,
# 	"('High', 'ABC')" FLOAT,
# 	"('High', 'ABMD')" FLOAT,
# 	"('High', 'ABT')" FLOAT,
# 	"('High', 'ACN')" FLOAT,
# 	"('High', 'ADBE')" FLOAT,
# 	"('High', 'ADI')" FLOAT,
# 	"('High', 'ADM')" FLOAT,
# 	"('High', 'ADP')" FLOAT,
# 	"('High', 'ADSK')" FLOAT,
# 	"('High', 'AEE')" FLOAT,
# 	"('High', 'AEP')" FLOAT,
# 	"('High', 'AES')" FLOAT,
# 	"('High', 'AFL')" FLOAT,
# 	"('High', 'AIG')" FLOAT,
# 	"('High', 'AIZ')" FLOAT,
# 	"('High', 'AJG')" FLOAT,
# 	"('High', 'AKAM')" FLOAT,
# 	"('High', 'ALB')" FLOAT,
# 	"('High', 'ALGN')" FLOAT,
# 	"('High', 'ALK')" FLOAT,
# 	"('High', 'ALL')" FLOAT,
# 	"('High', 'ALLE')" FLOAT,
# 	"('High', 'AMAT')" FLOAT,
# 	"('High', 'AMCR')" FLOAT,
# 	"('High', 'AMD')" FLOAT,
# 	"('High', 'AME')" FLOAT,
# 	"('High', 'AMGN')" FLOAT,
# 	"('High', 'AMP')" FLOAT,
# 	"('High', 'AMT')" FLOAT,
# 	"('High', 'AMZN')" FLOAT,
# 	"('High', 'ANET')" FLOAT,
# 	"('High', 'ANSS')" FLOAT,
# 	"('High', 'ANTM')" FLOAT,
# 	"('High', 'AON')" FLOAT,
# 	"('High', 'AOS')" FLOAT,
# 	"('High', 'APA')" FLOAT,
# 	"('High', 'APD')" FLOAT,
# 	"('High', 'APH')" FLOAT,
# 	"('High', 'APTV')" FLOAT,
# 	"('High', 'ARE')" FLOAT,
# 	"('High', 'ATO')" FLOAT,
# 	"('High', 'ATVI')" FLOAT,
# 	"('High', 'AVB')" FLOAT,
# 	"('High', 'AVGO')" FLOAT,
# 	"('High', 'AVY')" FLOAT,
# 	"('High', 'AWK')" FLOAT,
# 	"('High', 'AXP')" FLOAT,
# 	"('High', 'AZO')" FLOAT,
# 	"('High', 'BA')" FLOAT,
# 	"('High', 'BAC')" FLOAT,
# 	"('High', 'BAX')" FLOAT,
# 	"('High', 'BBWI')" FLOAT,
# 	"('High', 'BBY')" FLOAT,
# 	"('High', 'BDX')" FLOAT,
# 	"('High', 'BEN')" FLOAT,
# 	"('High', 'BF-B')" FLOAT,
# 	"('High', 'BIIB')" FLOAT,
# 	"('High', 'BIO')" FLOAT,
# 	"('High', 'BK')" FLOAT,
# 	"('High', 'BKNG')" FLOAT,
# 	"('High', 'BKR')" FLOAT,
# 	"('High', 'BLK')" FLOAT,
# 	"('High', 'BLL')" FLOAT,
# 	"('High', 'BMY')" FLOAT,
# 	"('High', 'BR')" FLOAT,
# 	"('High', 'BRK-B')" FLOAT,
# 	"('High', 'BSX')" FLOAT,
# 	"('High', 'BWA')" FLOAT,
# 	"('High', 'BXP')" FLOAT,
# 	"('High', 'C')" FLOAT,
# 	"('High', 'CAG')" FLOAT,
# 	"('High', 'CAH')" FLOAT,
# 	"('High', 'CARR')" FLOAT,
# 	"('High', 'CAT')" FLOAT,
# 	"('High', 'CB')" FLOAT,
# 	"('High', 'CBOE')" FLOAT,
# 	"('High', 'CBRE')" FLOAT,
# 	"('High', 'CCI')" FLOAT,
# 	"('High', 'CCL')" FLOAT,
# 	"('High', 'CDNS')" FLOAT,
# 	"('High', 'CDW')" FLOAT,
# 	"('High', 'CE')" FLOAT,
# 	"('High', 'CERN')" FLOAT,
# 	"('High', 'CF')" FLOAT,
# 	"('High', 'CFG')" FLOAT,
# 	"('High', 'CHD')" FLOAT,
# 	"('High', 'CHRW')" FLOAT,
# 	"('High', 'CHTR')" FLOAT,
# 	"('High', 'CI')" FLOAT,
# 	"('High', 'CINF')" FLOAT,
# 	"('High', 'CL')" FLOAT,
# 	"('High', 'CLX')" FLOAT,
# 	"('High', 'CMA')" FLOAT,
# 	"('High', 'CMCSA')" FLOAT,
# 	"('High', 'CME')" FLOAT,
# 	"('High', 'CMG')" FLOAT,
# 	"('High', 'CMI')" FLOAT,
# 	"('High', 'CMS')" FLOAT,
# 	"('High', 'CNC')" FLOAT,
# 	"('High', 'CNP')" FLOAT,
# 	"('High', 'COF')" FLOAT,
# 	"('High', 'COG')" FLOAT,
# 	"('High', 'COO')" FLOAT,
# 	"('High', 'COP')" FLOAT,
# 	"('High', 'COST')" FLOAT,
# 	"('High', 'CPB')" FLOAT,
# 	"('High', 'CPRT')" FLOAT,
# 	"('High', 'CRL')" FLOAT,
# 	"('High', 'CRM')" FLOAT,
# 	"('High', 'CSCO')" FLOAT,
# 	"('High', 'CSX')" FLOAT,
# 	"('High', 'CTAS')" FLOAT,
# 	"('High', 'CTLT')" FLOAT,
# 	"('High', 'CTSH')" FLOAT,
# 	"('High', 'CTVA')" FLOAT,
# 	"('High', 'CTXS')" FLOAT,
# 	"('High', 'CVS')" FLOAT,
# 	"('High', 'CVX')" FLOAT,
# 	"('High', 'CZR')" FLOAT,
# 	"('High', 'D')" FLOAT,
# 	"('High', 'DAL')" FLOAT,
# 	"('High', 'DD')" FLOAT,
# 	"('High', 'DE')" FLOAT,
# 	"('High', 'DFS')" FLOAT,
# 	"('High', 'DG')" FLOAT,
# 	"('High', 'DGX')" FLOAT,
# 	"('High', 'DHI')" FLOAT,
# 	"('High', 'DHR')" FLOAT,
# 	"('High', 'DIS')" FLOAT,
# 	"('High', 'DISCA')" FLOAT,
# 	"('High', 'DISCK')" FLOAT,
# 	"('High', 'DISH')" FLOAT,
# 	"('High', 'DLR')" FLOAT,
# 	"('High', 'DLTR')" FLOAT,
# 	"('High', 'DOV')" FLOAT,
# 	"('High', 'DOW')" FLOAT,
# 	"('High', 'DPZ')" FLOAT,
# 	"('High', 'DRE')" FLOAT,
# 	"('High', 'DRI')" FLOAT,
# 	"('High', 'DTE')" FLOAT,
# 	"('High', 'DUK')" FLOAT,
# 	"('High', 'DVA')" FLOAT,
# 	"('High', 'DVN')" FLOAT,
# 	"('High', 'DXC')" FLOAT,
# 	"('High', 'DXCM')" FLOAT,
# 	"('High', 'EA')" FLOAT,
# 	"('High', 'EBAY')" FLOAT,
# 	"('High', 'ECL')" FLOAT,
# 	"('High', 'ED')" FLOAT,
# 	"('High', 'EFX')" FLOAT,
# 	"('High', 'EIX')" FLOAT,
# 	"('High', 'EL')" FLOAT,
# 	"('High', 'EMN')" FLOAT,
# 	"('High', 'EMR')" FLOAT,
# 	"('High', 'ENPH')" FLOAT,
# 	"('High', 'EOG')" FLOAT,
# 	"('High', 'EQIX')" FLOAT,
# 	"('High', 'EQR')" FLOAT,
# 	"('High', 'ES')" FLOAT,
# 	"('High', 'ESS')" FLOAT,
# 	"('High', 'ETN')" FLOAT,
# 	"('High', 'ETR')" FLOAT,
# 	"('High', 'ETSY')" FLOAT,
# 	"('High', 'EVRG')" FLOAT,
# 	"('High', 'EW')" FLOAT,
# 	"('High', 'EXC')" FLOAT,
# 	"('High', 'EXPD')" FLOAT,
# 	"('High', 'EXPE')" FLOAT,
# 	"('High', 'EXR')" FLOAT,
# 	"('High', 'F')" FLOAT,
# 	"('High', 'FANG')" FLOAT,
# 	"('High', 'FAST')" FLOAT,
# 	"('High', 'FB')" FLOAT,
# 	"('High', 'FBHS')" FLOAT,
# 	"('High', 'FCX')" FLOAT,
# 	"('High', 'FDX')" FLOAT,
# 	"('High', 'FE')" FLOAT,
# 	"('High', 'FFIV')" FLOAT,
# 	"('High', 'FIS')" FLOAT,
# 	"('High', 'FISV')" FLOAT,
# 	"('High', 'FITB')" FLOAT,
# 	"('High', 'FLT')" FLOAT,
# 	"('High', 'FMC')" FLOAT,
# 	"('High', 'FOX')" FLOAT,
# 	"('High', 'FOXA')" FLOAT,
# 	"('High', 'FRC')" FLOAT,
# 	"('High', 'FRT')" FLOAT,
# 	"('High', 'FTNT')" FLOAT,
# 	"('High', 'FTV')" FLOAT,
# 	"('High', 'GD')" FLOAT,
# 	"('High', 'GE')" FLOAT,
# 	"('High', 'GILD')" FLOAT,
# 	"('High', 'GIS')" FLOAT,
# 	"('High', 'GL')" FLOAT,
# 	"('High', 'GLW')" FLOAT,
# 	"('High', 'GM')" FLOAT,
# 	"('High', 'GNRC')" FLOAT,
# 	"('High', 'GOOG')" FLOAT,
# 	"('High', 'GOOGL')" FLOAT,
# 	"('High', 'GPC')" FLOAT,
# 	"('High', 'GPN')" FLOAT,
# 	"('High', 'GPS')" FLOAT,
# 	"('High', 'GRMN')" FLOAT,
# 	"('High', 'GS')" FLOAT,
# 	"('High', 'GWW')" FLOAT,
# 	"('High', 'HAL')" FLOAT,
# 	"('High', 'HAS')" FLOAT,
# 	"('High', 'HBAN')" FLOAT,
# 	"('High', 'HBI')" FLOAT,
# 	"('High', 'HCA')" FLOAT,
# 	"('High', 'HD')" FLOAT,
# 	"('High', 'HES')" FLOAT,
# 	"('High', 'HIG')" FLOAT,
# 	"('High', 'HII')" FLOAT,
# 	"('High', 'HLT')" FLOAT,
# 	"('High', 'HOLX')" FLOAT,
# 	"('High', 'HON')" FLOAT,
# 	"('High', 'HPE')" FLOAT,
# 	"('High', 'HPQ')" FLOAT,
# 	"('High', 'HRL')" FLOAT,
# 	"('High', 'HSIC')" FLOAT,
# 	"('High', 'HST')" FLOAT,
# 	"('High', 'HSY')" FLOAT,
# 	"('High', 'HUM')" FLOAT,
# 	"('High', 'HWM')" FLOAT,
# 	"('High', 'IBM')" FLOAT,
# 	"('High', 'ICE')" FLOAT,
# 	"('High', 'IDXX')" FLOAT,
# 	"('High', 'IEX')" FLOAT,
# 	"('High', 'IFF')" FLOAT,
# 	"('High', 'ILMN')" FLOAT,
# 	"('High', 'INCY')" FLOAT,
# 	"('High', 'INFO')" FLOAT,
# 	"('High', 'INTC')" FLOAT,
# 	"('High', 'INTU')" FLOAT,
# 	"('High', 'IP')" FLOAT,
# 	"('High', 'IPG')" FLOAT,
# 	"('High', 'IPGP')" FLOAT,
# 	"('High', 'IQV')" FLOAT,
# 	"('High', 'IR')" FLOAT,
# 	"('High', 'IRM')" FLOAT,
# 	"('High', 'ISRG')" FLOAT,
# 	"('High', 'IT')" FLOAT,
# 	"('High', 'ITW')" FLOAT,
# 	"('High', 'IVZ')" FLOAT,
# 	"('High', 'J')" FLOAT,
# 	"('High', 'JBHT')" FLOAT,
# 	"('High', 'JCI')" FLOAT,
# 	"('High', 'JKHY')" FLOAT,
# 	"('High', 'JNJ')" FLOAT,
# 	"('High', 'JNPR')" FLOAT,
# 	"('High', 'JPM')" FLOAT,
# 	"('High', 'K')" FLOAT,
# 	"('High', 'KEY')" FLOAT,
# 	"('High', 'KEYS')" FLOAT,
# 	"('High', 'KHC')" FLOAT,
# 	"('High', 'KIM')" FLOAT,
# 	"('High', 'KLAC')" FLOAT,
# 	"('High', 'KMB')" FLOAT,
# 	"('High', 'KMI')" FLOAT,
# 	"('High', 'KMX')" FLOAT,
# 	"('High', 'KO')" FLOAT,
# 	"('High', 'KR')" FLOAT,
# 	"('High', 'KSU')" FLOAT,
# 	"('High', 'L')" FLOAT,
# 	"('High', 'LDOS')" FLOAT,
# 	"('High', 'LEG')" FLOAT,
# 	"('High', 'LEN')" FLOAT,
# 	"('High', 'LH')" FLOAT,
# 	"('High', 'LHX')" FLOAT,
# 	"('High', 'LIN')" FLOAT,
# 	"('High', 'LKQ')" FLOAT,
# 	"('High', 'LLY')" FLOAT,
# 	"('High', 'LMT')" FLOAT,
# 	"('High', 'LNC')" FLOAT,
# 	"('High', 'LNT')" FLOAT,
# 	"('High', 'LOW')" FLOAT,
# 	"('High', 'LRCX')" FLOAT,
# 	"('High', 'LUMN')" FLOAT,
# 	"('High', 'LUV')" FLOAT,
# 	"('High', 'LVS')" FLOAT,
# 	"('High', 'LW')" FLOAT,
# 	"('High', 'LYB')" FLOAT,
# 	"('High', 'LYV')" FLOAT,
# 	"('High', 'MA')" FLOAT,
# 	"('High', 'MAA')" FLOAT,
# 	"('High', 'MAR')" FLOAT,
# 	"('High', 'MAS')" FLOAT,
# 	"('High', 'MCD')" FLOAT,
# 	"('High', 'MCHP')" FLOAT,
# 	"('High', 'MCK')" FLOAT,
# 	"('High', 'MCO')" FLOAT,
# 	"('High', 'MDLZ')" FLOAT,
# 	"('High', 'MDT')" FLOAT,
# 	"('High', 'MET')" FLOAT,
# 	"('High', 'MGM')" FLOAT,
# 	"('High', 'MHK')" FLOAT,
# 	"('High', 'MKC')" FLOAT,
# 	"('High', 'MKTX')" FLOAT,
# 	"('High', 'MLM')" FLOAT,
# 	"('High', 'MMC')" FLOAT,
# 	"('High', 'MMM')" FLOAT,
# 	"('High', 'MNST')" FLOAT,
# 	"('High', 'MO')" FLOAT,
# 	"('High', 'MOS')" FLOAT,
# 	"('High', 'MPC')" FLOAT,
# 	"('High', 'MPWR')" FLOAT,
# 	"('High', 'MRK')" FLOAT,
# 	"('High', 'MRNA')" FLOAT,
# 	"('High', 'MRO')" FLOAT,
# 	"('High', 'MS')" FLOAT,
# 	"('High', 'MSCI')" FLOAT,
# 	"('High', 'MSFT')" FLOAT,
# 	"('High', 'MSI')" FLOAT,
# 	"('High', 'MTB')" FLOAT,
# 	"('High', 'MTD')" FLOAT,
# 	"('High', 'MU')" FLOAT,
# 	"('High', 'MXIM')" FLOAT,
# 	"('High', 'NCLH')" FLOAT,
# 	"('High', 'NDAQ')" FLOAT,
# 	"('High', 'NEE')" FLOAT,
# 	"('High', 'NEM')" FLOAT,
# 	"('High', 'NFLX')" FLOAT,
# 	"('High', 'NI')" FLOAT,
# 	"('High', 'NKE')" FLOAT,
# 	"('High', 'NLOK')" FLOAT,
# 	"('High', 'NLSN')" FLOAT,
# 	"('High', 'NOC')" FLOAT,
# 	"('High', 'NOV')" FLOAT,
# 	"('High', 'NOW')" FLOAT,
# 	"('High', 'NRG')" FLOAT,
# 	"('High', 'NSC')" FLOAT,
# 	"('High', 'NTAP')" FLOAT,
# 	"('High', 'NTRS')" FLOAT,
# 	"('High', 'NUE')" FLOAT,
# 	"('High', 'NVDA')" FLOAT,
# 	"('High', 'NVR')" FLOAT,
# 	"('High', 'NWL')" FLOAT,
# 	"('High', 'NWS')" FLOAT,
# 	"('High', 'NWSA')" FLOAT,
# 	"('High', 'NXPI')" FLOAT,
# 	"('High', 'O')" FLOAT,
# 	"('High', 'ODFL')" FLOAT,
# 	"('High', 'OGN')" FLOAT,
# 	"('High', 'OKE')" FLOAT,
# 	"('High', 'OMC')" FLOAT,
# 	"('High', 'ORCL')" FLOAT,
# 	"('High', 'ORLY')" FLOAT,
# 	"('High', 'OTIS')" FLOAT,
# 	"('High', 'OXY')" FLOAT,
# 	"('High', 'PAYC')" FLOAT,
# 	"('High', 'PAYX')" FLOAT,
# 	"('High', 'PBCT')" FLOAT,
# 	"('High', 'PCAR')" FLOAT,
# 	"('High', 'PEAK')" FLOAT,
# 	"('High', 'PEG')" FLOAT,
# 	"('High', 'PENN')" FLOAT,
# 	"('High', 'PEP')" FLOAT,
# 	"('High', 'PFE')" FLOAT,
# 	"('High', 'PFG')" FLOAT,
# 	"('High', 'PG')" FLOAT,
# 	"('High', 'PGR')" FLOAT,
# 	"('High', 'PH')" FLOAT,
# 	"('High', 'PHM')" FLOAT,
# 	"('High', 'PKG')" FLOAT,
# 	"('High', 'PKI')" FLOAT,
# 	"('High', 'PLD')" FLOAT,
# 	"('High', 'PM')" FLOAT,
# 	"('High', 'PNC')" FLOAT,
# 	"('High', 'PNR')" FLOAT,
# 	"('High', 'PNW')" FLOAT,
# 	"('High', 'POOL')" FLOAT,
# 	"('High', 'PPG')" FLOAT,
# 	"('High', 'PPL')" FLOAT,
# 	"('High', 'PRGO')" FLOAT,
# 	"('High', 'PRU')" FLOAT,
# 	"('High', 'PSA')" FLOAT,
# 	"('High', 'PSX')" FLOAT,
# 	"('High', 'PTC')" FLOAT,
# 	"('High', 'PVH')" FLOAT,
# 	"('High', 'PWR')" FLOAT,
# 	"('High', 'PXD')" FLOAT,
# 	"('High', 'PYPL')" FLOAT,
# 	"('High', 'QCOM')" FLOAT,
# 	"('High', 'QRVO')" FLOAT,
# 	"('High', 'RCL')" FLOAT,
# 	"('High', 'RE')" FLOAT,
# ...
# 	"('Open', 'WDC')" FLOAT,
# 	"('Open', 'WEC')" FLOAT,
# 	"('Open', 'WELL')" FLOAT,
# 	"('Open', 'WFC')" FLOAT,
# 	"('Open', 'WHR')" FLOAT,
# 	"('Open', 'WLTW')" FLOAT,
# 	"('Open', 'WM')" FLOAT,
# 	"('Open', 'WMB')" FLOAT,
# 	"('Open', 'WMT')" FLOAT,
# 	"('Open', 'WRB')" FLOAT,
# 	"('Open', 'WRK')" FLOAT,
# 	"('Open', 'WST')" FLOAT,
# 	"('Open', 'WU')" FLOAT,
# 	"('Open', 'WY')" FLOAT,
# 	"('Open', 'WYNN')" FLOAT,
# 	"('Open', 'XEL')" FLOAT,
# 	"('Open', 'XLNX')" FLOAT,
# 	"('Open', 'XOM')" FLOAT,
# 	"('Open', 'XRAY')" FLOAT,
# 	"('Open', 'XYL')" FLOAT,
# 	"('Open', 'YUM')" FLOAT,
# 	"('Open', 'ZBH')" FLOAT,
# 	"('Open', 'ZBRA')" FLOAT,
# 	"('Open', 'ZION')" FLOAT,
# 	"('Open', 'ZTS')" FLOAT,
# 	"('Volume', 'A')" BIGINT,
# 	"('Volume', 'AAL')" BIGINT,
# 	"('Volume', 'AAP')" BIGINT,
# 	"('Volume', 'AAPL')" BIGINT,
# 	"('Volume', 'ABBV')" BIGINT,
# 	"('Volume', 'ABC')" BIGINT,
# 	"('Volume', 'ABMD')" BIGINT,
# 	"('Volume', 'ABT')" BIGINT,
# 	"('Volume', 'ACN')" BIGINT,
# 	"('Volume', 'ADBE')" BIGINT,
# 	"('Volume', 'ADI')" BIGINT,
# 	"('Volume', 'ADM')" BIGINT,
# 	"('Volume', 'ADP')" BIGINT,
# 	"('Volume', 'ADSK')" BIGINT,
# 	"('Volume', 'AEE')" BIGINT,
# 	"('Volume', 'AEP')" BIGINT,
# 	"('Volume', 'AES')" BIGINT,
# 	"('Volume', 'AFL')" BIGINT,
# 	"('Volume', 'AIG')" BIGINT,
# 	"('Volume', 'AIZ')" BIGINT,
# 	"('Volume', 'AJG')" BIGINT,
# 	"('Volume', 'AKAM')" BIGINT,
# 	"('Volume', 'ALB')" BIGINT,
# 	"('Volume', 'ALGN')" BIGINT,
# 	"('Volume', 'ALK')" BIGINT,
# 	"('Volume', 'ALL')" BIGINT,
# 	"('Volume', 'ALLE')" BIGINT,
# 	"('Volume', 'AMAT')" BIGINT,
# 	"('Volume', 'AMCR')" BIGINT,
# 	"('Volume', 'AMD')" BIGINT,
# 	"('Volume', 'AME')" BIGINT,
# 	"('Volume', 'AMGN')" BIGINT,
# 	"('Volume', 'AMP')" BIGINT,
# 	"('Volume', 'AMT')" BIGINT,
# 	"('Volume', 'AMZN')" BIGINT,
# 	"('Volume', 'ANET')" BIGINT,
# 	"('Volume', 'ANSS')" BIGINT,
# 	"('Volume', 'ANTM')" BIGINT,
# 	"('Volume', 'AON')" BIGINT,
# 	"('Volume', 'AOS')" BIGINT,
# 	"('Volume', 'APA')" BIGINT,
# 	"('Volume', 'APD')" BIGINT,
# 	"('Volume', 'APH')" BIGINT,
# 	"('Volume', 'APTV')" BIGINT,
# 	"('Volume', 'ARE')" BIGINT,
# 	"('Volume', 'ATO')" BIGINT,
# 	"('Volume', 'ATVI')" BIGINT,
# 	"('Volume', 'AVB')" BIGINT,
# 	"('Volume', 'AVGO')" BIGINT,
# 	"('Volume', 'AVY')" BIGINT,
# 	"('Volume', 'AWK')" BIGINT,
# 	"('Volume', 'AXP')" BIGINT,
# 	"('Volume', 'AZO')" BIGINT,
# 	"('Volume', 'BA')" BIGINT,
# 	"('Volume', 'BAC')" BIGINT,
# 	"('Volume', 'BAX')" BIGINT,
# 	"('Volume', 'BBWI')" BIGINT,
# 	"('Volume', 'BBY')" BIGINT,
# 	"('Volume', 'BDX')" BIGINT,
# 	"('Volume', 'BEN')" BIGINT,
# 	"('Volume', 'BF-B')" BIGINT,
# 	"('Volume', 'BIIB')" BIGINT,
# 	"('Volume', 'BIO')" BIGINT,
# 	"('Volume', 'BK')" BIGINT,
# 	"('Volume', 'BKNG')" BIGINT,
# 	"('Volume', 'BKR')" BIGINT,
# 	"('Volume', 'BLK')" BIGINT,
# 	"('Volume', 'BLL')" BIGINT,
# 	"('Volume', 'BMY')" BIGINT,
# 	"('Volume', 'BR')" BIGINT,
# 	"('Volume', 'BRK-B')" BIGINT,
# 	"('Volume', 'BSX')" BIGINT,
# 	"('Volume', 'BWA')" BIGINT,
# 	"('Volume', 'BXP')" BIGINT,
# 	"('Volume', 'C')" BIGINT,
# 	"('Volume', 'CAG')" BIGINT,
# 	"('Volume', 'CAH')" BIGINT,
# 	"('Volume', 'CARR')" BIGINT,
# 	"('Volume', 'CAT')" BIGINT,
# 	"('Volume', 'CB')" BIGINT,
# 	"('Volume', 'CBOE')" BIGINT,
# 	"('Volume', 'CBRE')" BIGINT,
# 	"('Volume', 'CCI')" BIGINT,
# 	"('Volume', 'CCL')" BIGINT,
# 	"('Volume', 'CDNS')" BIGINT,
# 	"('Volume', 'CDW')" BIGINT,
# 	"('Volume', 'CE')" BIGINT,
# 	"('Volume', 'CERN')" BIGINT,
# 	"('Volume', 'CF')" BIGINT,
# 	"('Volume', 'CFG')" BIGINT,
# 	"('Volume', 'CHD')" BIGINT,
# 	"('Volume', 'CHRW')" BIGINT,
# 	"('Volume', 'CHTR')" BIGINT,
# 	"('Volume', 'CI')" BIGINT,
# 	"('Volume', 'CINF')" BIGINT,
# 	"('Volume', 'CL')" BIGINT,
# 	"('Volume', 'CLX')" BIGINT,
# 	"('Volume', 'CMA')" BIGINT,
# 	"('Volume', 'CMCSA')" BIGINT,
# 	"('Volume', 'CME')" BIGINT,
# 	"('Volume', 'CMG')" BIGINT,
# 	"('Volume', 'CMI')" BIGINT,
# 	"('Volume', 'CMS')" BIGINT,
# 	"('Volume', 'CNC')" BIGINT,
# 	"('Volume', 'CNP')" BIGINT,
# 	"('Volume', 'COF')" BIGINT,
# 	"('Volume', 'COG')" BIGINT,
# 	"('Volume', 'COO')" BIGINT,
# 	"('Volume', 'COP')" BIGINT,
# 	"('Volume', 'COST')" BIGINT,
# 	"('Volume', 'CPB')" BIGINT,
# 	"('Volume', 'CPRT')" BIGINT,
# 	"('Volume', 'CRL')" BIGINT,
# 	"('Volume', 'CRM')" BIGINT,
# 	"('Volume', 'CSCO')" BIGINT,
# 	"('Volume', 'CSX')" BIGINT,
# 	"('Volume', 'CTAS')" BIGINT,
# 	"('Volume', 'CTLT')" BIGINT,
# 	"('Volume', 'CTSH')" BIGINT,
# 	"('Volume', 'CTVA')" BIGINT,
# 	"('Volume', 'CTXS')" BIGINT,
# 	"('Volume', 'CVS')" BIGINT,
# 	"('Volume', 'CVX')" BIGINT,
# 	"('Volume', 'CZR')" BIGINT,
# 	"('Volume', 'D')" BIGINT,
# 	"('Volume', 'DAL')" BIGINT,
# 	"('Volume', 'DD')" BIGINT,
# 	"('Volume', 'DE')" BIGINT,
# 	"('Volume', 'DFS')" BIGINT,
# 	"('Volume', 'DG')" BIGINT,
# 	"('Volume', 'DGX')" BIGINT,
# 	"('Volume', 'DHI')" BIGINT,
# 	"('Volume', 'DHR')" BIGINT,
# 	"('Volume', 'DIS')" BIGINT,
# 	"('Volume', 'DISCA')" BIGINT,
# 	"('Volume', 'DISCK')" BIGINT,
# 	"('Volume', 'DISH')" BIGINT,
# 	"('Volume', 'DLR')" BIGINT,
# 	"('Volume', 'DLTR')" BIGINT,
# 	"('Volume', 'DOV')" BIGINT,
# 	"('Volume', 'DOW')" BIGINT,
# 	"('Volume', 'DPZ')" BIGINT,
# 	"('Volume', 'DRE')" BIGINT,
# 	"('Volume', 'DRI')" BIGINT,
# 	"('Volume', 'DTE')" BIGINT,
# 	"('Volume', 'DUK')" BIGINT,
# 	"('Volume', 'DVA')" BIGINT,
# 	"('Volume', 'DVN')" BIGINT,
# 	"('Volume', 'DXC')" BIGINT,
# 	"('Volume', 'DXCM')" BIGINT,
# 	"('Volume', 'EA')" BIGINT,
# 	"('Volume', 'EBAY')" BIGINT,
# 	"('Volume', 'ECL')" BIGINT,
# 	"('Volume', 'ED')" BIGINT,
# 	"('Volume', 'EFX')" BIGINT,
# 	"('Volume', 'EIX')" BIGINT,
# 	"('Volume', 'EL')" BIGINT,
# 	"('Volume', 'EMN')" BIGINT,
# 	"('Volume', 'EMR')" BIGINT,
# 	"('Volume', 'ENPH')" BIGINT,
# 	"('Volume', 'EOG')" BIGINT,
# 	"('Volume', 'EQIX')" BIGINT,
# 	"('Volume', 'EQR')" BIGINT,
# 	"('Volume', 'ES')" BIGINT,
# 	"('Volume', 'ESS')" BIGINT,
# 	"('Volume', 'ETN')" BIGINT,
# 	"('Volume', 'ETR')" BIGINT,
# 	"('Volume', 'ETSY')" BIGINT,
# 	"('Volume', 'EVRG')" BIGINT,
# 	"('Volume', 'EW')" BIGINT,
# 	"('Volume', 'EXC')" BIGINT,
# 	"('Volume', 'EXPD')" BIGINT,
# 	"('Volume', 'EXPE')" BIGINT,
# 	"('Volume', 'EXR')" BIGINT,
# 	"('Volume', 'F')" BIGINT,
# 	"('Volume', 'FANG')" BIGINT,
# 	"('Volume', 'FAST')" BIGINT,
# 	"('Volume', 'FB')" BIGINT,
# 	"('Volume', 'FBHS')" BIGINT,
# 	"('Volume', 'FCX')" BIGINT,
# 	"('Volume', 'FDX')" BIGINT,
# 	"('Volume', 'FE')" BIGINT,
# 	"('Volume', 'FFIV')" BIGINT,
# 	"('Volume', 'FIS')" BIGINT,
# 	"('Volume', 'FISV')" BIGINT,
# 	"('Volume', 'FITB')" BIGINT,
# 	"('Volume', 'FLT')" BIGINT,
# 	"('Volume', 'FMC')" BIGINT,
# 	"('Volume', 'FOX')" BIGINT,
# 	"('Volume', 'FOXA')" BIGINT,
# 	"('Volume', 'FRC')" BIGINT,
# 	"('Volume', 'FRT')" BIGINT,
# 	"('Volume', 'FTNT')" BIGINT,
# 	"('Volume', 'FTV')" BIGINT,
# 	"('Volume', 'GD')" BIGINT,
# 	"('Volume', 'GE')" BIGINT,
# 	"('Volume', 'GILD')" BIGINT,
# 	"('Volume', 'GIS')" BIGINT,
# 	"('Volume', 'GL')" BIGINT,
# 	"('Volume', 'GLW')" BIGINT,
# 	"('Volume', 'GM')" BIGINT,
# 	"('Volume', 'GNRC')" BIGINT,
# 	"('Volume', 'GOOG')" BIGINT,
# 	"('Volume', 'GOOGL')" BIGINT,
# 	"('Volume', 'GPC')" BIGINT,
# 	"('Volume', 'GPN')" BIGINT,
# 	"('Volume', 'GPS')" BIGINT,
# 	"('Volume', 'GRMN')" BIGINT,
# 	"('Volume', 'GS')" BIGINT,
# 	"('Volume', 'GWW')" BIGINT,
# 	"('Volume', 'HAL')" BIGINT,
# 	"('Volume', 'HAS')" BIGINT,
# 	"('Volume', 'HBAN')" BIGINT,
# 	"('Volume', 'HBI')" BIGINT,
# 	"('Volume', 'HCA')" BIGINT,
# 	"('Volume', 'HD')" BIGINT,
# 	"('Volume', 'HES')" BIGINT,
# 	"('Volume', 'HIG')" BIGINT,
# 	"('Volume', 'HII')" BIGINT,
# 	"('Volume', 'HLT')" BIGINT,
# 	"('Volume', 'HOLX')" BIGINT,
# 	"('Volume', 'HON')" BIGINT,
# 	"('Volume', 'HPE')" BIGINT,
# 	"('Volume', 'HPQ')" BIGINT,
# 	"('Volume', 'HRL')" BIGINT,
# 	"('Volume', 'HSIC')" BIGINT,
# 	"('Volume', 'HST')" BIGINT,
# 	"('Volume', 'HSY')" BIGINT,
# 	"('Volume', 'HUM')" BIGINT,
# 	"('Volume', 'HWM')" BIGINT,
# 	"('Volume', 'IBM')" BIGINT,
# 	"('Volume', 'ICE')" BIGINT,
# 	"('Volume', 'IDXX')" BIGINT,
# 	"('Volume', 'IEX')" BIGINT,
# 	"('Volume', 'IFF')" BIGINT,
# 	"('Volume', 'ILMN')" BIGINT,
# 	"('Volume', 'INCY')" BIGINT,
# 	"('Volume', 'INFO')" BIGINT,
# 	"('Volume', 'INTC')" BIGINT,
# 	"('Volume', 'INTU')" BIGINT,
# 	"('Volume', 'IP')" BIGINT,
# 	"('Volume', 'IPG')" BIGINT,
# 	"('Volume', 'IPGP')" BIGINT,
# 	"('Volume', 'IQV')" BIGINT,
# 	"('Volume', 'IR')" BIGINT,
# 	"('Volume', 'IRM')" BIGINT,
# 	"('Volume', 'ISRG')" BIGINT,
# 	"('Volume', 'IT')" BIGINT,
# 	"('Volume', 'ITW')" BIGINT,
# 	"('Volume', 'IVZ')" BIGINT,
# 	"('Volume', 'J')" BIGINT,
# 	"('Volume', 'JBHT')" BIGINT,
# 	"('Volume', 'JCI')" BIGINT,
# 	"('Volume', 'JKHY')" BIGINT,
# 	"('Volume', 'JNJ')" BIGINT,
# 	"('Volume', 'JNPR')" BIGINT,
# 	"('Volume', 'JPM')" BIGINT,
# 	"('Volume', 'K')" BIGINT,
# 	"('Volume', 'KEY')" BIGINT,
# 	"('Volume', 'KEYS')" BIGINT,
# 	"('Volume', 'KHC')" BIGINT,
# 	"('Volume', 'KIM')" BIGINT,
# 	"('Volume', 'KLAC')" BIGINT,
# 	"('Volume', 'KMB')" BIGINT,
# 	"('Volume', 'KMI')" BIGINT,
# 	"('Volume', 'KMX')" BIGINT,
# 	"('Volume', 'KO')" BIGINT,
# 	"('Volume', 'KR')" BIGINT,
# 	"('Volume', 'KSU')" BIGINT,
# 	"('Volume', 'L')" BIGINT,
# 	"('Volume', 'LDOS')" BIGINT,
# 	"('Volume', 'LEG')" BIGINT,
# 	"('Volume', 'LEN')" BIGINT,
# 	"('Volume', 'LH')" BIGINT,
# 	"('Volume', 'LHX')" BIGINT,
# 	"('Volume', 'LIN')" BIGINT,
# 	"('Volume', 'LKQ')" BIGINT,
# 	"('Volume', 'LLY')" BIGINT,
# 	"('Volume', 'LMT')" BIGINT,
# 	"('Volume', 'LNC')" BIGINT,
# 	"('Volume', 'LNT')" BIGINT,
# 	"('Volume', 'LOW')" BIGINT,
# 	"('Volume', 'LRCX')" BIGINT,
# 	"('Volume', 'LUMN')" BIGINT,
# 	"('Volume', 'LUV')" BIGINT,
# 	"('Volume', 'LVS')" BIGINT,
# 	"('Volume', 'LW')" BIGINT,
# 	"('Volume', 'LYB')" BIGINT,
# 	"('Volume', 'LYV')" BIGINT,
# 	"('Volume', 'MA')" BIGINT,
# 	"('Volume', 'MAA')" BIGINT,
# 	"('Volume', 'MAR')" BIGINT,
# 	"('Volume', 'MAS')" BIGINT,
# 	"('Volume', 'MCD')" BIGINT,
# 	"('Volume', 'MCHP')" BIGINT,
# 	"('Volume', 'MCK')" BIGINT,
# 	"('Volume', 'MCO')" BIGINT,
# 	"('Volume', 'MDLZ')" BIGINT,
# 	"('Volume', 'MDT')" BIGINT,
# 	"('Volume', 'MET')" BIGINT,
# 	"('Volume', 'MGM')" BIGINT,
# 	"('Volume', 'MHK')" BIGINT,
# 	"('Volume', 'MKC')" BIGINT,
# 	"('Volume', 'MKTX')" BIGINT,
# 	"('Volume', 'MLM')" BIGINT,
# 	"('Volume', 'MMC')" BIGINT,
# 	"('Volume', 'MMM')" BIGINT,
# 	"('Volume', 'MNST')" BIGINT,
# 	"('Volume', 'MO')" BIGINT,
# 	"('Volume', 'MOS')" BIGINT,
# 	"('Volume', 'MPC')" BIGINT,
# 	"('Volume', 'MPWR')" BIGINT,
# 	"('Volume', 'MRK')" BIGINT,
# 	"('Volume', 'MRNA')" BIGINT,
# 	"('Volume', 'MRO')" BIGINT,
# 	"('Volume', 'MS')" BIGINT,
# 	"('Volume', 'MSCI')" BIGINT,
# 	"('Volume', 'MSFT')" BIGINT,
# 	"('Volume', 'MSI')" BIGINT,
# 	"('Volume', 'MTB')" BIGINT,
# 	"('Volume', 'MTD')" BIGINT,
# 	"('Volume', 'MU')" BIGINT,
# 	"('Volume', 'MXIM')" BIGINT,
# 	"('Volume', 'NCLH')" BIGINT,
# 	"('Volume', 'NDAQ')" BIGINT,
# 	"('Volume', 'NEE')" BIGINT,
# 	"('Volume', 'NEM')" BIGINT,
# 	"('Volume', 'NFLX')" BIGINT,
# 	"('Volume', 'NI')" BIGINT,
# 	"('Volume', 'NKE')" BIGINT,
# 	"('Volume', 'NLOK')" BIGINT,
# 	"('Volume', 'NLSN')" BIGINT,
# 	"('Volume', 'NOC')" BIGINT,
# 	"('Volume', 'NOV')" BIGINT,
# 	"('Volume', 'NOW')" BIGINT,
# 	"('Volume', 'NRG')" BIGINT,
# 	"('Volume', 'NSC')" BIGINT,
# 	"('Volume', 'NTAP')" BIGINT,
# 	"('Volume', 'NTRS')" BIGINT,
# 	"('Volume', 'NUE')" BIGINT,
# 	"('Volume', 'NVDA')" BIGINT,
# 	"('Volume', 'NVR')" BIGINT,
# 	"('Volume', 'NWL')" BIGINT,
# 	"('Volume', 'NWS')" BIGINT,
# 	"('Volume', 'NWSA')" BIGINT,
# 	"('Volume', 'NXPI')" BIGINT,
# 	"('Volume', 'O')" BIGINT,
# 	"('Volume', 'ODFL')" BIGINT,
# 	"('Volume', 'OGN')" BIGINT,
# 	"('Volume', 'OKE')" BIGINT,
# 	"('Volume', 'OMC')" BIGINT,
# 	"('Volume', 'ORCL')" BIGINT,
# 	"('Volume', 'ORLY')" BIGINT,
# 	"('Volume', 'OTIS')" BIGINT,
# 	"('Volume', 'OXY')" BIGINT,
# 	"('Volume', 'PAYC')" BIGINT,
# 	"('Volume', 'PAYX')" BIGINT,
# 	"('Volume', 'PBCT')" BIGINT,
# 	"('Volume', 'PCAR')" BIGINT,
# 	"('Volume', 'PEAK')" BIGINT,
# 	"('Volume', 'PEG')" BIGINT,
# 	"('Volume', 'PENN')" BIGINT,
# 	"('Volume', 'PEP')" BIGINT,
# 	"('Volume', 'PFE')" BIGINT,
# 	"('Volume', 'PFG')" BIGINT,
# 	"('Volume', 'PG')" BIGINT,
# 	"('Volume', 'PGR')" BIGINT,
# 	"('Volume', 'PH')" BIGINT,
# 	"('Volume', 'PHM')" BIGINT,
# 	"('Volume', 'PKG')" BIGINT,
# 	"('Volume', 'PKI')" BIGINT,
# 	"('Volume', 'PLD')" BIGINT,
# 	"('Volume', 'PM')" BIGINT,
# 	"('Volume', 'PNC')" BIGINT,
# 	"('Volume', 'PNR')" BIGINT,
# 	"('Volume', 'PNW')" BIGINT,
# 	"('Volume', 'POOL')" BIGINT,
# 	"('Volume', 'PPG')" BIGINT,
# 	"('Volume', 'PPL')" BIGINT,
# 	"('Volume', 'PRGO')" BIGINT,
# 	"('Volume', 'PRU')" BIGINT,
# 	"('Volume', 'PSA')" BIGINT,
# 	"('Volume', 'PSX')" BIGINT,
# 	"('Volume', 'PTC')" BIGINT,
# 	"('Volume', 'PVH')" BIGINT,
# 	"('Volume', 'PWR')" BIGINT,
# 	"('Volume', 'PXD')" BIGINT,
# 	"('Volume', 'PYPL')" BIGINT,
# 	"('Volume', 'QCOM')" BIGINT,
# 	"('Volume', 'QRVO')" BIGINT,
# 	"('Volume', 'RCL')" BIGINT,
# 	"('Volume', 'RE')" BIGINT,
# 	"('Volume', 'REG')" BIGINT,
# 	"('Volume', 'REGN')" BIGINT,
# 	"('Volume', 'RF')" BIGINT,
# 	"('Volume', 'RHI')" BIGINT,
# 	"('Volume', 'RJF')" BIGINT,
# 	"('Volume', 'RL')" BIGINT,
# 	"('Volume', 'RMD')" BIGINT,
# 	"('Volume', 'ROK')" BIGINT,
# 	"('Volume', 'ROL')" BIGINT,
# 	"('Volume', 'ROP')" BIGINT,
# 	"('Volume', 'ROST')" BIGINT,
# 	"('Volume', 'RSG')" BIGINT,
# 	"('Volume', 'RTX')" BIGINT,
# 	"('Volume', 'SBAC')" BIGINT,
# 	"('Volume', 'SBUX')" BIGINT,
# 	"('Volume', 'SCHW')" BIGINT,
# 	"('Volume', 'SEE')" BIGINT,
# 	"('Volume', 'SHW')" BIGINT,
# 	"('Volume', 'SIVB')" BIGINT,
# 	"('Volume', 'SJM')" BIGINT,
# 	"('Volume', 'SLB')" BIGINT,
# 	"('Volume', 'SNA')" BIGINT,
# 	"('Volume', 'SNPS')" BIGINT,
# 	"('Volume', 'SO')" BIGINT,
# 	"('Volume', 'SPG')" BIGINT,
# 	"('Volume', 'SPGI')" BIGINT,
# 	"('Volume', 'SRE')" BIGINT,
# 	"('Volume', 'STE')" BIGINT,
# 	"('Volume', 'STT')" BIGINT,
# 	"('Volume', 'STX')" BIGINT,
# 	"('Volume', 'STZ')" BIGINT,
# 	"('Volume', 'SWK')" BIGINT,
# 	"('Volume', 'SWKS')" BIGINT,
# 	"('Volume', 'SYF')" BIGINT,
# 	"('Volume', 'SYK')" BIGINT,
# 	"('Volume', 'SYY')" BIGINT,
# 	"('Volume', 'T')" BIGINT,
# 	"('Volume', 'TAP')" BIGINT,
# 	"('Volume', 'TDG')" BIGINT,
# 	"('Volume', 'TDY')" BIGINT,
# 	"('Volume', 'TEL')" BIGINT,
# 	"('Volume', 'TER')" BIGINT,
# 	"('Volume', 'TFC')" BIGINT,
# 	"('Volume', 'TFX')" BIGINT,
# 	"('Volume', 'TGT')" BIGINT,
# 	"('Volume', 'TJX')" BIGINT,
# 	"('Volume', 'TMO')" BIGINT,
# 	"('Volume', 'TMUS')" BIGINT,
# 	"('Volume', 'TPR')" BIGINT,
# 	"('Volume', 'TRMB')" BIGINT,
# 	"('Volume', 'TROW')" BIGINT,
# 	"('Volume', 'TRV')" BIGINT,
# 	"('Volume', 'TSCO')" BIGINT,
# 	"('Volume', 'TSLA')" BIGINT,
# 	"('Volume', 'TSN')" BIGINT,
# 	"('Volume', 'TT')" BIGINT,
# 	"('Volume', 'TTWO')" BIGINT,
# 	"('Volume', 'TWTR')" BIGINT,
# 	"('Volume', 'TXN')" BIGINT,
# 	"('Volume', 'TXT')" BIGINT,
# 	"('Volume', 'TYL')" BIGINT,
# 	"('Volume', 'UA')" BIGINT,
# 	"('Volume', 'UAA')" BIGINT,
# 	"('Volume', 'UAL')" BIGINT,
# 	"('Volume', 'UDR')" BIGINT,
# 	"('Volume', 'UHS')" BIGINT,
# 	"('Volume', 'ULTA')" BIGINT,
# 	"('Volume', 'UNH')" BIGINT,
# 	"('Volume', 'UNM')" BIGINT,
# 	"('Volume', 'UNP')" BIGINT,
# 	"('Volume', 'UPS')" BIGINT,
# 	"('Volume', 'URI')" BIGINT,
# 	"('Volume', 'USB')" BIGINT,
# 	"('Volume', 'V')" BIGINT,
# 	"('Volume', 'VFC')" BIGINT,
# 	"('Volume', 'VIAC')" BIGINT,
# 	"('Volume', 'VLO')" BIGINT,
# 	"('Volume', 'VMC')" BIGINT,
# 	"('Volume', 'VNO')" BIGINT,
# 	"('Volume', 'VRSK')" BIGINT,
# 	"('Volume', 'VRSN')" BIGINT,
# 	"('Volume', 'VRTX')" BIGINT,
# 	"('Volume', 'VTR')" BIGINT,
# 	"('Volume', 'VTRS')" BIGINT,
# 	"('Volume', 'VZ')" BIGINT,
# 	"('Volume', 'WAB')" BIGINT,
# 	"('Volume', 'WAT')" BIGINT,
# 	"('Volume', 'WBA')" BIGINT,
# 	"('Volume', 'WDC')" BIGINT,
# 	"('Volume', 'WEC')" BIGINT,
# 	"('Volume', 'WELL')" BIGINT,
# 	"('Volume', 'WFC')" BIGINT,
# 	"('Volume', 'WHR')" BIGINT,
# 	"('Volume', 'WLTW')" BIGINT,
# 	"('Volume', 'WM')" BIGINT,
# 	"('Volume', 'WMB')" BIGINT,
# 	"('Volume', 'WMT')" BIGINT,
# 	"('Volume', 'WRB')" BIGINT,
# 	"('Volume', 'WRK')" BIGINT,
# 	"('Volume', 'WST')" BIGINT,
# 	"('Volume', 'WU')" BIGINT,
# 	"('Volume', 'WY')" BIGINT,
# 	"('Volume', 'WYNN')" BIGINT,
# 	"('Volume', 'XEL')" BIGINT,
# 	"('Volume', 'XLNX')" BIGINT,
# 	"('Volume', 'XOM')" BIGINT,
# 	"('Volume', 'XRAY')" BIGINT,
# 	"('Volume', 'XYL')" BIGINT,
# 	"('Volume', 'YUM')" BIGINT,
# 	"('Volume', 'ZBH')" BIGINT,
# 	"('Volume', 'ZBRA')" BIGINT,
# 	"('Volume', 'ZION')" BIGINT,
# 	"('Volume', 'ZTS')" BIGINT
# )
#
# ]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
sp_data_test = pd.read_sql_table('sp_data', con=engine)

sp_data_test

# %%
sp_data_test.columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

sp_data_test

# %%
# new_table= """
# CREATE TABLE new_table LIKE sp_data_test

# ALTER TABLE new_table CHANGE 'Column 0' 'Extention1'

# """

# %%
# sp_data_test2 = pd.read_sql_table('new_table', con=engine)

# sp_data_test2

# %%
engine.execute(insert_data,)

# %%
query="""
SELECT *
FROM (
SELECT)
"""

results=engine.execute(query)

# %%
csv_path = Path("Stock_Data/Stock_Data.json")

# %%
stock_dict = {}

# %%
sp_data_j = sp_data.to_json()

# %%
type(stock_dict)

# %%
type(sp_data_j)

# %%
sp_data_j = json.loads(sp_data_j)
type(sp_data_j)

# %%
print(json.dumps(sp_data_j, indent=4))

# %%
# reading the JSON data using json.load()
# file = 'data.json'
# with open(file) as train_file:
#     dict_train = json.load(train_file)

# converting json dataset from dictionary to dataframe
train = pd.DataFrame.from_dict(sp_data_j, orient='index')
train.reset_index(level=0, inplace=True)

# %%
train

# %%
with open(csv_path, 'w') as outfile:
     json.dump(sp_data.to_json(), outfile, indent=4)

# %%
with open(csv_path, "r") as infile:
    stock_dict = json.dump(infile)
    
stock_dict

# %%
json_file = open(csv_path, "r").read()
# stock_d = json.load(json_file)
# json_file.close()
# print(json.dumps(stock_d, indent=4, sort_keys=True))
# data = urlopen(q).read()
json_data = json.loads(json_file) # DECODE THE STRING 
with open('output.json', 'w') as out:
    json.dump(json_data, out, indent=4) # DO NOT CALL STR ON IT AGAIN

print(json.dumps(out))

# %%
def ForwardPE():
    tick_list = []
    forwardPE = []
    count = 0
    for ticker in sp5_tickers:
        info = yf.Ticker(ticker).info
        info["Ticker"] = ticker
        forwardPE.append(info["forwardPE"])
        tick_list.append(info["Ticker"])
        count+=1
        print(count)
    pe_df = pd.DataFrame(data=forwardPE, index=tick_list, columns=["Forward P/E"])
    pe_df.sort_values(by="Forward P/E", ascending=False, inplace=True)
    
    return pe_df
# fin = yf.Ticker("MSFT").info

# %%
ForwardPE()

# %%
# def calcRSI (ticker):
#     data = yf.download(ticker, period="5y", groupby="Ticker")
#     data["Moving_Avg_200_Days"] = data["Adj Close"].rolling(window=200).mean()
#     data["Price_Change"] = data["Adj Close"].pct_change()
#     data["Gains"] = data["Price_Change"].apply(lambda x: x if x > 0 else 0)
#     data["Losses"] = data["Price_Change"].apply(lambda x: abs(x) if x < 0 else 0)
#     data["Avg_Up"] = data["Gains"].ewm(span=19).mean()
#     data["Avg_Down"] = data["Losses"].ewm(span=19).mean()
#     data = data.dropna()
#     data["RS"] = data["Avg_Up"]/data["Avg_Down"]
#     data["RSI"] = data["RS"].apply(lambda x: 100 - (100/(x+1)))
#     return data

# %%
def calcRSI (ticker):
    data = yf.download(ticker, start=start_date,end=end_date, group_by="Ticker")
    data["Ticker"] = ticker
#     data["Moving_Avg_200_Days"] = data["Adj Close"].rolling(window=200).mean()
    data["Price_Change"] = data["Adj Close"].pct_change()
#     temp1 = data['Price_Change']
    data['Gains'] = data.loc[:,"Price_Change"].apply(lambda x: x if x > 0 else 0)
#     data["Gains"] = data.iloc[:,7].apply(lambda x: x if x > 0 else 0)
    data["Losses"] = data.loc[:,"Price_Change"].apply(lambda x: abs(x) if x < 0 else 0)
#     data["Losses"] = data.iloc[:,7].apply(lambda x: abs(x) if x < 0 else 0)
#     temp2 = data["Gains"]
#     temp3 = data["Losses"]
    data["Avg_Up"] = data.loc[:,"Gains"].ewm(com=13,adjust=False, min_periods=14).mean()
#     temp4 = data["Avg_Up"]
    data["Avg_Down"] = data.loc[:, "Losses"].ewm(com=13,adjust=False, min_periods=14).mean()
#     temp5 = data["Avg_Down"]

#     temp6 = temp4/temp5
    data["RS"] = data.loc[:, "Avg_Up"]/data.loc[:,"Avg_Down"]
    data["RSI"] = data.loc[:,"RS"].apply(lambda x: 100 - (100/(x+1)))
    data = data.dropna()
#     temp7 = data["RSI"]
#     output_df = pd.DataFrame(columns=["Ticker", "RSI"])
#     output_df = output_df.append({"Ticker" : ticker,
#                                  "RSI" : temp7},
#                                 ignore_index=True)
    today = data.iloc[-1]
#     output_df = pd.DataFrame(columns=["Ticker","RSI"])
#     output_df = pd.merge(output_df,today[["Ticker", "RSI"]], on="Ticker", how="left")
    return today

# %%
calcRSI(sp500_tickers[0])

# %%
sp5_tickers= ['MMM', 'ABT', 'ABBV', 'ABMD', 'ACN']

# %%
# join_data = pd.DataFrame(index="Tickers",columns="RSI")

# %%
def Todays_RSI_Hi():
    stock_tick_list = []
    stock_rsi_list = []
    count = 0
#     join_data = pd.DataFrame()
    for stock in sp5_tickers:
        stockRSI = calcRSI(stock)
        stock_tick_list.append(stockRSI["Ticker"])
        stock_rsi_list.append(stockRSI["RSI"])
        count+=1
        print(count)
    rsi_df_hi = pd.DataFrame(data=(stock_rsi_list), index=stock_tick_list, columns=["RSI"])
    rsi_df_hi.sort_values(by=["RSI"], ascending=False,inplace=True)

    return rsi_df_hi.head()

# %%
fig = Todays_RSI_Hi()

# %%
fig

# %%
def Todays_RSI_Low():
    stock_tick_list = []
    stock_rsi_list = []
    count = 0
#     join_data = pd.DataFrame()
    for stock in sp5_tickers:
        stockRSI = calcRSI(stock)
        stock_tick_list.append(stockRSI["Ticker"])
        stock_rsi_list.append(stockRSI["RSI"])
        count+=1
        print(count)
    rsi_df_low = pd.DataFrame(data=(stock_rsi_list), index=stock_tick_list, columns=["RSI"])
    rsi_df_low = rsi_df_low.sort_values(by=["RSI"],ascending=True)

    return rsi_df_low

# %%
fig2 = Todays_RSI_Low()

# %%
fig2

# %%
aapl_data = yf.download('AAPL', period="1mo")
aapl_data

# %%
aapl_data['Ticker'] = 'AAPL'
aapl_data

# %%
wmt_data = yf.download("WMT", period="1mo")
wmt_data

# %%
combined = pd.merge(aapl_data, wmt_data, how="left", on=['Date'])

# %%
combined

# %%
""
